# %%
import json
import re
import spacy as sp
import pandas as pd

with open('data/all_subjects.json') as f:
    subjects = json.load(f)

print(f'There are {len(subjects)} subjects in the dataset')
# Out:
# There are 640 subjects in the dataset

# %%
for subject in subjects:
    for category in subject['content']

# %% [markdown]
# #### Create dataframe with useful information

# %%
data = {
    'id': [],
    'subject_title': [],
    'summary': [],
    'synonyms': [],
    'icpc': []
}

for subject in subjects:
    data['id'].append(subject['id']) #extract the id 
    data['subject_title'].append(subject['title']) #extract the title of the subject
    data['summary'].append(subject['summary']) #extract the text of the subject
    synonyms = subject['synonyms'] #extract the synonyms of the subject
    if synonyms:
        data['synonyms'].append(', '.join(synonyms))
    else:
        data['synonyms'].append(None)
    icpc_codes = subject['codes']['icpc'] #extract the icpc code of the subject
    if icpc_codes:
        data['icpc'].append(', '.join(icpc_codes))
    else:
        data['icpc'].append(None)  # if there is no icpc code, give None

df = pd.DataFrame(data)

#clean the text in summary
html_pattern = re.compile(r'<[^>]+>')
escape_pattern = re.compile(r'\\u[0-9a-fA-F]{4}')
newline_pattern = re.compile(r'(\n|\t|\xa0|\u202f)')

clean_text = [newline_pattern.sub(' ', escape_pattern.sub(' ', html_pattern.sub(' ', item))) for item in df['summary']]

df['summary'] = [item.strip() for item in clean_text]

df
# Out:
#         id                     subject_title  \
# 0    11381                          Bijtwond
# 1    11463                         Open been
# 2    11323        Dikke enkels of onderbenen
# 3    11165                          Wondroos
# 4    16408           Prik tegen pneumokokken
# ..     ...                               ...
# 635  12640                          Vitiligo
# 636  22377                      Downsyndroom
# 637  16796               Trombose in het oog
# 638  12081        Dikkere borsten bij mannen
# 639  15705  Overgevoelig voor contrastmiddel
#
#                                                summary  \
# 0    Een bijtwond komt door een beet van een dier o...
# 1    Een open been is een wond op het onderbeen die...
# 2    Uw enkels of onderbenen kunnen dik worden door...
# 3    Wondroos is een ontsteking van de huid.     He...
# 4    Pneumokokken zijn bacteriën.  Vooral ouderen k...
# ..                                                 ...
# 635  Vitiligo is een aandoening waarbij de pigmentc...
# 636  Kinderen met downsyndroom:    hebben een verst...
# 637  Bij trombose in het oog zitten 1 of meer bloed...
# 638  Dikkere borsten komen bij pubers en bij mannen...
# 639  U kunt overgevoelig zijn voor een contrastmidd...
#
#                                     synonyms      icpc
# 0                                    Gebeten       S13
# 1                               Ulcus cruris       S97
# 2                                     Oedeem       K07
# 3                     Erysipelas, Cellulitis    S76.01
# 4                           Pneumokokkenprik       A44
# ..                                       ...       ...
# 635                                     None      None
# 636                                     None       A90
# 637                                     None  K94, F94
# 638  Gynaecomastie, Borstzwelling bij mannen    Y29.01
# 639                                     None  A12, A85
#
# [640 rows x 5 columns]

# %%
#give me the number of categories
print(f'There are {len(df)} categories in the dataset')
# Out:
# There are 640 categories in the dataset

# %% [markdown]
# #### Exploration of subjects and ICPC codes

# %%
no_icpc = []
icpc_present = []

for i in range(len(df)):
    if df['icpc'][i] is None:
        no_icpc.append((df['id'][i], df['subject_title'][i]))
    else:
        icpc_present.append((df['id'][i], df['subject_title'][i], df['icpc'][i]))

print(f'Number of subjects with no ICPC codes: {len(no_icpc)}')
print(f'Number of subjects with ICPC codes: {len(icpc_present)}')

print("\nSubjects with no ICPC codes:")
for subject_id, subject_title in no_icpc:
    print(f'ID: {subject_id}, Title: {subject_title}')
# Out:
# Number of subjects with no ICPC codes: 48
# Number of subjects with ICPC codes: 592
#
# Subjects with no ICPC codes:
# ID: 22397, Title: PEG-sonde
# ID: 11150, Title: Bloed uit de vagina
# ID: 26987, Title: Nadenken over je leven
# ID: 25746, Title: Psychische klachten en werk
# ID: 12635, Title: Te langzaam werkende schildklier
# ID: 11417, Title: Zwanger
# ID: 28624, Title: Slecht zien en blind zijn
# ID: 21360, Title: Kijkoperatie van de knie
# ID: 12642, Title: Pijnstillers zoals ibuprofen, naproxen en diclofenac (NSAID)
# ID: 21160, Title: Bloedverdunners
# ID: 20507, Title: Röntgenfoto's
# ID: 17228, Title: MRI
# ID: 20140, Title: CT-scan
# ID: 11664, Title: Vitamine D
# ID: 12016, Title: Ziekte van Scheuermann
# ID: 21410, Title: Pijn onder in buik en in bekken
# ID: 12361, Title: Ziek kind
# ID: 12588, Title: Sterilisatie bij de vrouw
# ID: 12584, Title: Hormoonring
# ID: 19449, Title: Echo
# ID: 27403, Title: Hoge druk in de hersenen
# ID: 23875, Title: Uitzaaiingen in de hersenen
# ID: 22777, Title: Veranderingen in zorg als je 18 wordt
# ID: 11816, Title: Golfarm
# ID: 11698, Title: Groei kind
# ID: 17602, Title: Plekje op de voorhuid
# ID: 11986, Title: Seksuele klachten mannen
# ID: 26726, Title: Minder goed zien bij kinderen door hersenschade voor of rond de geboorte
# ID: 11592, Title: Hoogteziekte
# ID: 12600, Title: Gescheurd trommelvlies
# ID: 11705, Title: Koorts
# ID: 11720, Title: Aangezichtspijn
# ID: 24732, Title: Mastocytose
# ID: 12639, Title: Onderzoeken van het hart
# ID: 20438, Title: Ruggenprik
# ID: 24166, Title: Apenpokken
# ID: 21594, Title: Kind stopt even met ademen
# ID: 11189, Title: Vijfde ziekte
# ID: 12090, Title: Ebola
# ID: 11616, Title: Verstopt oor
# ID: 11751, Title: Ingegroeide teennagel
# ID: 20821, Title: Kijkoperatie in de buik
# ID: 17428, Title: Te vroeg gesloten schedelnaden
# ID: 11689, Title: Schmallenberg-virus
# ID: 16900, Title: Vochtblaasje in het netvlies
# ID: 12135, Title: Vogelgriep
# ID: 12014, Title: Bloed ophoesten
# ID: 12640, Title: Vitiligo

# %%
icpc_present
# Out:
# [(11381, 'Bijtwond', 'S13'),
#  (11463, 'Open been', 'S97'),
#  (11323, 'Dikke enkels of onderbenen', 'K07'),
#  (11165, 'Wondroos', 'S76.01'),
#  (16408, 'Prik tegen pneumokokken', 'A44'),
#  (11314, 'Eczeem', 'S87'),
#  (11923, 'Eetprobleem', 'T05, T06'),
#  (28622, 'Contacteczeem', 'S88'),
#  (11098, 'Depressie', 'P03, P77, P76'),
#  (11438, 'Zon en zonnebrand', 'S14'),
#  (11243, 'Eczeem met schilfers op hoofd, gezicht of oren', 'S86'),
#  (11429, 'Lange tijd of vaak neusklachten', 'R97, R07'),
#  (11594, 'Allergie', 'A12'),
#  (17786, 'Eczeem door erfelijke aanleg', 'S87'),
#  (11596, 'Droge huid', 's21'),
#  (11668, 'Jeuk', 's02'),
#  (11385, 'Hooikoorts', 'R97'),
#  (12278, 'Ontsteking van de huid rond de mond', 'S88'),
#  (11184, 'Ziekte van Parkinson', 'N87'),
#  (24122, 'Zwanger en corona', 'R83.03'),
#  (24126, 'Corona in het ziekenhuis', 'R83.03'),
#  (24128, 'Na corona', 'R83.03'),
#  (24124, 'Corona hebben', 'R83.03'),
#  (23992, 'Coronaprik', 'R83.03'),
#  (15757, 'Corona', 'R83'),
#  (24136, 'Lang klachten na corona', 'R83.03'),
#  (23990, 'Corona voorkomen', 'R83.03'),
#  (24130, 'Naaste met corona', 'R83.03, Z22'),
#  (11878, 'Levenseinde', 'A69.01'),
#  (11916, 'Darmkanker', 'D16, D75'),
#  (11102, 'Artrose', 'L91, L90, L89, L84, L20'),
#  (22056, 'Artrose in de knie', 'L90'),
#  (11221, 'Knieklachten', 'L99, L94, L90, L15, L78, L96'),
#  (27321, 'Intensive care (IC)', 'A07'),
#  (11549, 'Q-koorts', 'A78'),
#  (26412, 'Overgewicht bij kinderen', 'T83, T82'),
#  (11630, 'Gezond leven', 'P17, T5, T83, T91'),
#  (11523, 'Ziekte van Pfeiffer', 'A75'),
#  (11387, 'Keelpijn', 'r76, R72, R21.01'),
#  (11247, 'Gewrichtsklachten', 'L20'),
#  (11265, 'Reactieve gewrichtsontsteking', 'M90'),
#  (11261, 'Reumatoïde artritis', 'N93, L88'),
#  (11134, 'Jicht', 'T92'),
#  (12462, 'Kunstheup', 'L89, L75, L13'),
#  (12458, 'Kunstknie', 'L90'),
#  (11181, 'Hartaanval', 'K76, K75, K74'),
#  (28299, 'Werk en privé-leven', 'Z05, Z29'),
#  (11968,
#   'Communicatie, hoorproblemen en verstandelijke beperkingen',
#   'P85, H86'),
#  (11467, 'Slecht horen', 'H02, H84, H86'),
#  (20498, 'Kijkonderzoek van de darm', 'D75; D78; D99; D93; D94'),
#  (28922, 'Darmkanker opsporen', 'A97'),
#  (12522, 'Alvleesklierkanker', 'D76'),
#  (11125, 'Bloed uit de anus (poepgat)', 'D16'),
#  (11918, 'Gezondheidstest', 'A97'),
#  (26698, 'Darmpoliepen', 'D78; D99'),
#  (12673, 'Eierstokkanker', 'x77'),
#  (11294, 'Borstkanker opsporen', 'X26, X76, A97'),
#  (17066, 'Borstvergroting', 'X29'),
#  (11292, 'Mastopathie', 'X88'),
#  (12340, 'Borstkanker', 'X76'),
#  (12594, 'Verandering van een borst', 'x19'),
#  (11235, 'Hernia in de rug', 'L86'),
#  (25968, 'Ander merk medicijn', 'A13'),
#  (11345, 'Ziekte van Dupuytren', 'L99.03, L87'),
#  (12288, 'Melanoom', 'S77'),
#  (12625, 'Basaalcelkanker', 'S77'),
#  (21070, 'Plekje op de huid', 'S99, S77'),
#  (12415, 'Ouderdomswrat', 'S99'),
#  (11639, 'Moedervlekken', 'S82, S77'),
#  (11811, 'Vetbultje', 'S78'),
#  (12034, 'Huidkanker', 'S77'),
#  (12623, 'Plaveiselcelkanker', 'S77'),
#  (19921, 'Aardbeivlek', 'S81'),
#  (12088, 'Bipolaire stoornis', 'P73.02'),
#  (11935, 'Psychose', 'P98'),
#  (11432, 'Miskraam', 'W82'),
#  (15853, 'Ongesteld en veel bloedverlies', 'X06'),
#  (12392, 'Buitenbaarmoederlijke zwangerschap', 'W80'),
#  (11237, 'Diabetes type 2', 'T90'),
#  (11173, 'Hidradenitis', 'S92.02'),
#  (26410, 'Overgewicht bij volwassenen', 'T83, T82'),
#  (12471, 'Keizersnede', 'W92, W78'),
#  (11459, 'Psoriasis', 'S91'),
#  (12230,
#   'Psychische klachten bij volwassenen',
#   'P99, P76, P74, P73, P72, P29, P02'),
#  (15140, 'Dikke ogen of lippen', 'A12.02'),
#  (11955, 'Eikenprocessierups', 's02, A88'),
#  (11383, 'Gestoken door een insect', 'S12'),
#  (11138, 'Netelroos', 'S98'),
#  (12618, 'Diabetes type 1', 'T90.01'),
#  (13403, 'Persoonlijkheidsstoornis', 'P80'),
#  (12115, 'Autisme', 'P99'),
#  (11207, 'Angst- en piekerstoornis', 'P74'),
#  (11850, 'ADHD', 'P21'),
#  (11397, 'Risico hart- en vaatziekten verlagen', 'K49.01, K75, K91'),
#  (11894, 'Geweld thuis', 'Z12.02'),
#  (12387, 'Seksueel geweld', 'Z25.01, Z12'),
#  (22143, 'Dissociatieve stoornis', 'P79, P99'),
#  (12267, 'Problemen thuis', 'P04, P22, P23, Z12, Z16'),
#  (11307, 'Etalagebenen', 'K92.01'),
#  (12759, 'Heroïneverslaving', 'P19'),
#  (13163, 'Sociale-angststoornis', 'P79'),
#  (11691, 'Dwangstoornis', 'P79'),
#  (12382, 'Denken aan zelfmoord', 'P77'),
#  (12086, 'Functioneel-neurologische stoornis', 'P99, P75'),
#  (12596, 'Kindermishandeling', 'Z16'),
#  (13487, 'Stemmen horen', 'P98'),
#  (14029, 'Medicijnen bij psychose', 'P71'),
#  (21394, 'Onderzoek door ouderen-arts in het ziekenhuis', 'A05'),
#  (11779, 'Alcohol', 'P15'),
#  (11863, 'Eenzaamheid', 'Z29'),
#  (11793, 'Boulimia', 'T06.02'),
#  (12598, 'Eetbuistoornis', 'T06'),
#  (12922, 'Eetstoornis', 'p11, T06'),
#  (11527, 'Snel dingen vergeten', 'P20'),
#  (16170, 'Wensen voor zorg en behandeling', 'A20'),
#  (11899, 'Onverklaarde lichamelijke klachten', 'A50'),
#  (11312, 'Delier', 'P71'),
#  (11675, 'Moeheid', 'Z29, P06, B80, A04'),
#  (12027, 'Premenstrueel syndroom', 'X09'),
#  (12589, 'Somberheid', 'P03'),
#  (12597, 'Anorexia', 'T06.01'),
#  (12607, 'Depressie na de bevalling', 'p76.01, P76'),
#  (25732, 'Winterdepressie', 'P03; P76'),
#  (12468, 'Angst', 'P01'),
#  (11791, 'Taaislijmziekte', 'T99.10'),
#  (27833, 'Baby zat tijdens bevalling vast met schouder', 'W92'),
#  (11686, 'Nierschade', 'U99, U98'),
#  (11479, 'Schildklier-problemen', 'T86, T85, A91'),
#  (12636, 'Te snel werkende schildklier', 'T85, A91'),
#  (22521, 'Zwanger van een drieling', 'W78, W84'),
#  (14527, 'Zwanger, misselijk en overgeven', 'D09, W05'),
#  (14113, 'Zwanger en jeuk', 's02, W29'),
#  (26046, 'Galstuwing als je zwanger bent', 'S02;W29'),
#  (14372, 'Zwanger van een tweeling', 'W78, W84'),
#  (12215, 'Sarcoïdose', 'R83, R05'),
#  (25058, 'Reuma-medicijnen en zwanger', 'L88, W78'),
#  (14647, 'Uveïtis', 'F73'),
#  (28584, 'Veel te zwaar en zwanger', 'T82, W78'),
#  (28449, 'Te vroeg gebroken vliezen', 'W29;W90'),
#  (27697, 'Zaadbalkanker', 'Y78'),
#  (12119, 'Strakke voorhuid', 'y81'),
#  (12572, 'Eikelontsteking', 'Y75'),
#  (12250, 'Colitis ulcerosa', 'D94'),
#  (12225, 'Ziekte van Crohn', 'D94'),
#  (12599,
#   'Verlamde arm, verlamd been, scheve mond of niet goed praten, slikken of zien',
#   'N18; N19;'),
#  (11239, 'Pijn onder in de rug', 'L03'),
#  (12185, 'Zenuwpijn', 's01, n94, n92, n29, N03'),
#  (12099, 'Pijn aan zijkant heup', 'L13'),
#  (12159, 'Vernauwing van het wervelkanaal', 'K92'),
#  (11848, 'Meralgia paresthetica', 'N94.04'),
#  (12121, 'Pijn in de kuit', 'L14'),
#  (12609, 'Seksuele klachten vrouwen', 'P07, P08'),
#  (11193, 'De pil', 'W11'),
#  (11533, 'Overgang', 'X11'),
#  (22829, 'Baarmoederkanker', 'x77'),
#  (11684, 'Endometriose', 'X99, X02'),
#  (11822, 'Botontkalking', 'L95'),
#  (22102, 'Operatie voor de stand van mijn been bij knie-artrose', 'L90'),
#  (11511, 'Overspannen', 'P78'),
#  (11903, 'Epilepsie', 'N88'),
#  (12123, 'Trombosebeen', 'K94'),
#  (12616, 'O- en X-benen bij kinderen', 'L98'),
#  (21474, 'Kunst-schouder', 'L08, L91'),
#  (12333, 'Gebroken heup', 'L75'),
#  (11508, 'Minder goed zien bij kinderen', 'F91, F05'),
#  (12196, 'Minder goed zien bij volwassenen', 'F05, F91'),
#  (11199, 'Boezem-fibrilleren', 'K78, K04'),
#  (11298, 'COPD', 'R95, R91, R02'),
#  (11422, 'Lui oog', 'F05'),
#  (16746, 'Trillende ogen', 'F14'),
#  (11545, 'Scheelzien bij kinderen', 'F95'),
#  (12581, 'Retinitis pigmentosa', 'F83, F94'),
#  (11840, 'Mouches volantes', 'F04'),
#  (12201, 'Glasvochtloslating', 'F99, F04'),
#  (11393, 'Droge ogen', 'F13'),
#  (12203, 'Maculadegeneratie', 'F84'),
#  (11842, 'Staar', 'F92'),
#  (12213, 'Glaucoom', 'F93'),
#  (11274, 'Maagklachten', 'D87, D03, D02, A49'),
#  (11090, 'Hartkramp', 'K74'),
#  (12442, 'Ontsteking van de haarzakjes', 'S11.01'),
#  (12446, 'Bult met pus bij de anus', 'D95.03'),
#  (11537, 'Talgkliercyste', 'S93.01'),
#  (11148, 'Steenpuist', 'R73, S10'),
#  (11602, 'Zweten', 'A09'),
#  (12444, 'Ontsteking in de bilspleet', 'S85'),
#  (15983, 'Prikpil', 'W14, W11'),
#  (12586, 'Hormoonstaafje', 'W14'),
#  (11650, 'Stoppen met roken', 'P17'),
#  (11374, 'Hoesten', 'R05'),
#  (12285, 'Bronchitis', 'R78, R05'),
#  (15048, 'Lachgas', 'P19'),
#  (23251, 'Drugs', 'P19, Z13, Z21'),
#  (12608, 'Ontstoken slijmbeurs in de knie', 'L99.01, L70, L15'),
#  (15797, 'Knieschijf uit de kom', 'L15, L80'),
#  (15799, 'Meniscus gescheurd', 'L96'),
#  (15795, 'Knieband verrekt of gescheurd', 'L96'),
#  (11470, 'Osgood-Schlatter-knie', 'L94.02'),
#  (11552, 'Springersknie', 'l99.02, L15'),
#  (12615, 'Lopersknie', 'L15, L99'),
#  (15801, 'Gekneusde of verrekte knie', 'L78'),
#  (11495, 'Verzwikte enkel', 'L77, L16'),
#  (11539, 'Pijn aan de knieschijf bij bewegen', 'L15, L99'),
#  (11643, 'Bult in de knieholte', 'L99'),
#  (11952, 'Sport-blessure', 'A80'),
#  (12173, 'Drukplek', 'S97'),
#  (11175, 'Hartfalen', 'K77'),
#  (11191, 'Te veel afgevallen', 'T91'),
#  (12254, 'Begeleiding van de bedrijfsarts', 'Z05'),
#  (24226, 'Nachtdiensten en gezondheid', 'Z05'),
#  (11443, 'Nierbekkenontsteking', 'U70'),
#  (11520, 'Pijn en pijnstillers', 'A01'),
#  (11672, 'Buikpijn', 'D01, D02, D06, D08, D12, D73, D87'),
#  (11426, 'Hoornvlies-beschadiging', 'F79.02'),
#  (11501, 'Vuiltje of splinter in het oog', 'F76'),
#  (11891, 'Rosacea', 's99.03'),
#  (16584, 'Klachten bij contactlenzen', 'F18'),
#  (12283, 'Verstopte traanbuis', 'F80, F73'),
#  (11518, 'Pijnlijk rood bultje in het ooglid', 'F72'),
#  (11628, 'Hard bultje in het ooglid dat geen pijn doet', 'F72, F13, F02'),
#  (13174, "Vieze oogjes bij baby's", 'F80'),
#  (16940, 'Vleugelvlies op het oog', 'F99.04'),
#  (16976, 'Tranende ogen', 'F03'),
#  (11391, 'Episcleritis', 'F99.05'),
#  (11203, 'Rood oog', 'F71'),
#  (16572, 'Oogontsteking door herpes', 'F73'),
#  (16594, 'Uitpuilende ogen', 'T85'),
#  (16960, 'Geel bultje op oogwit', 'F99'),
#  (11483, 'Ontstoken ooglid-randen', 'F72'),
#  (11493, 'Rode plek in het oogwit door een kapot bloedvaatje', 'F75.01'),
#  (13094, 'Hoornvlies-beschadiging door fel licht', 'F79.01'),
#  (13152, 'Klap op oog', 'F75'),
#  (27987, 'Besnijdenis', 'X82'),
#  (12997,
#   'Psychische klachten als je jong bent',
#   'p24, P99, P21, p11, P22, P29'),
#  (12133, 'Aderontsteking met een bloedprop', 'K94.02'),
#  (11709, 'Medicijnen bij ouderen', 'A13, A49'),
#  (12126, 'Longembolie', 'K93'),
#  (11580, 'Spataderen', 'w77, K95'),
#  (12227, 'Gekneusde of gebroken rib', 'L81.02, L76.05'),
#  (11887, 'Hartkloppingen', 'K04'),
#  (12328, 'Zwangerschaps-diabetes', 'W84'),
#  (11154, 'Koortsstuip', 'N07, A03'),
#  (28321, 'Klompvoet bij baby', 'L82'),
#  (12380, 'Tetanus', 'N72'),
#  (28189, 'Zwanger en contrastmiddel', 'W78'),
#  (12117, 'Flauwvallen', 'A06'),
#  (12021, 'Pijn op de borst', 'R01, K01, L04'),
#  (11547, 'Psychosociale problemen', 'Z29, Z04, P29'),
#  (12031, "Kuitkrampen 's nachts", 'L14;L18'),
#  (12002, 'ME/CVS', 'A04'),
#  (11364, 'Spanningshoofdpijn', 'N02'),
#  (11395, 'Slecht slapen', 'P06'),
#  (11716, 'Slaapapneu', 'P06.01'),
#  (11854, 'Rusteloze benen', 'N04'),
#  (11372, 'Hoofdpijn', 'N01'),
#  (12069, 'Stress', 'P01, P02'),
#  (11575, 'Voedsel-allergie', 'D99'),
#  (16606, 'Keratoconus', 'F99'),
#  (18658, 'Gevoelig voor sommige groenten, fruit of noten', 'A12'),
#  (12595, 'Astma bij kinderen', 'R96, R02'),
#  (11256, 'Astma bij volwassenen', 'R96, R02'),
#  (11960, 'Ramadan en gezondheid', 'Z04'),
#  (12057, 'Snurken', 'R06, r04'),
#  (12073, 'Vitamine B12', 'B81'),
#  (14189, 'DNA-onderzoek bij medicijnen', 'A13, A84, A85'),
#  (11267, 'Hoge bloeddruk', 'K86, K87'),
#  (11276, 'Cholesterol', 'T93.01'),
#  (11079, 'Beroerte', 'K90, K89'),
#  (11171, 'Zwanger worden', 'A97, W15, Y10'),
#  (11253, 'Penis minder stijf', 'P08, Y07'),
#  (14337, 'Mody diabetes', 'T90'),
#  (22697, 'Te veel of verkeerd ademen', 'R98'),
#  (12010, 'Vernauwing of afsluiting beenslagader', 'K92'),
#  (11368, 'Prikkelbare darm syndroom (PDS)', 'D93'),
#  (19807, 'Zwakke plek in een bloedvat in het hoofd', 'K90, K99'),
#  (26356, 'Maagverkleining', 'T82'),
#  (12617, 'Chronische pijn', 'A85, A01'),
#  (11205, 'Bloedarmoede', 'B80, B81, B82'),
#  (11569, 'Verstopping bij volwassenen', 'D12'),
#  (11491, 'Diverticulitis', 'D92'),
#  (11376, 'Koortslip', 'S71'),
#  (11965, 'Omgaan met warm weer', 'A88'),
#  (24252, 'Gezond eten', 'T05, T91'),
#  (26532, 'Gescheurde zwakke plek in een bloedvat in het hoofd', 'K90'),
#  (11933, 'Dikkere lymfeklier', 'B02;'),
#  (12966, 'Cannabis bij een ziekte', 'A01'),
#  (12316, 'Ongesteldheid uitstellen', 'X10'),
#  (11600, 'Overbeharing', 'S24'),
#  (12637, 'Ontsteking door schimmel in de vagina', 'X14, X72'),
#  (11489, 'Polycysteus-ovarium-syndroom (PCOS)', 'T99.06'),
#  (12045, 'Vleesboom', 'X78'),
#  (11288, 'Vocht uit de vagina', 'X14'),
#  (11230, 'Uitstrijkje baarmoederhals', 'X85, X86, A97'),
#  (11559, 'Schouderklachten', 'L08'),
#  (12274, 'Bijbal-ontsteking', 'Y74'),
#  (11309, 'Blaasontsteking', 'U71, U29'),
#  (12666, 'Problemen met plassen bij vrouwen', 'U04, U29, U71'),
#  (12217, 'Sepsis', 'A03, a02'),
#  (11477, 'Slijm of pus uit penis', 'Y71, Y03, U72, Y99.03'),
#  (11531, 'Prostaatontsteking', 'Y73'),
#  (11565, 'Plas niet goed kunnen ophouden bij vrouwen', 'U04'),
#  (11929, 'Blaasontsteking bij kinderen', 'U71, U29'),
#  (12497, 'Blaaskanker', 'U76'),
#  (11525, 'Niersteen', 'U95'),
#  (11833, 'Buikpijn bij kinderen', 'D87, D73, D12, D08, D06, D02, D01'),
#  (11866, 'Problemen met plassen bij mannen', 'u02, U04, U05, Y85'),
#  (12147, 'Overactieve blaas', 'U04.02, U04, u02'),
#  (25448, 'Bedplassen bij volwassenen', 'P12'),
#  (26788, 'Litteken dat klachten geeft', 'S99'),
#  (11831, 'Lichen sclerosus', 's02, D05, Y04, S02;D05;Y04;X16, S99'),
#  (11327, 'Griep', 'R80'),
#  (11678, 'Scheurtjes in de anus (poepgat)', 'D04, D16, D95'),
#  (12619, 'Ontsteking van de endeldarm', 'D16'),
#  (12019, 'Jeuk in de bilspleet', 'D05'),
#  (11083, 'Aambeien', 'K96'),
#  (11110, 'Duizelig', 'n17'),
#  (11499, 'Pseudokroep', 'R77.01'),
#  (19153, 'Gele huid of geel oogwit bij baby', 'D13'),
#  (12241, 'Waterwratjes', 's95'),
#  (11389, 'Likdoorn', 'S20'),
#  (11169, 'Wratten', 'S03'),
#  (11781,
#   'Ontsteking in gewrichten van rug en bekken (axiale spondyloartritis)',
#   'L88'),
#  (11590, 'Mondproblemen', 'D83, D82, D19, D20, S71'),
#  (11789, 'Haartong', 'D83'),
#  (12189, 'Slechte adem', 'D20'),
#  (11456, 'Slijmoor', 'H72'),
#  (12603, 'Middenoor-ontsteking', 'H01, H71, H72, H74'),
#  (12601, 'Oorpijn', 'H71, H70'),
#  (12141, 'Val of klap op het hoofd', 'N80, N79, A80'),
#  (12394, 'Wonden', 'S14, S17, S18, S19'),
#  (27531, 'Veel te vroeg bevallen', 'A93'),
#  (11826, 'Scheenbeenklachten', 'L14'),
#  (12353, 'Achillespees-blessure', 'l99.02'),
#  (12163, 'Pijn aan een pees', 'l99.02'),
#  (12583, 'Hormoonpleister om niet zwanger te worden', 'W14'),
#  (12587, 'Spiraaltje', 'W12, W10'),
#  (11113, 'Zwangerschap voorkomen', 'W11, W10, W12, W14, S96'),
#  (12585, 'Condooms', 'Y14.01'),
#  (11107, 'Sterilisatie bij de man', 'Y13'),
#  (11087, 'Acne', 'S96'),
#  (11556, 'Heupdysplasie', 'L13'),
#  (13796, 'Koorts na een prik tegen kinderziektes', 'A03'),
#  (18762, 'Prikken tegen ziektes (kinderen)', 'A44'),
#  (12745, 'Angst bij kinderen', 'P01; P74;'),
#  (11144, 'Hypochondrie', 'P75'),
#  (13995, 'Kalmeringsmiddelen', 'P01, P74'),
#  (11406, 'Fobie', 'P79.01'),
#  (11403, 'Paniekaanvallen', 'P74'),
#  (12638, 'Morning-afterpil', 'W10, W12'),
#  (11604, 'Borstvoeding', 'W19;W95'),
#  (12092, 'Onbedoeld zwanger', 'w83, w79'),
#  (27939, 'Diabetes en zwanger', 'T90'),
#  (11682, 'Onderzoek baby in de buik', 'A97, A99'),
#  (20104, "Vergrote nieren bij baby's", 'U99'),
#  (12674, 'Slikproblemen', 'D21'),
#  (11132, 'Gordelroos', 'S70'),
#  (21952, 'Pijn bij kanker', 'A87, A01'),
#  (11737, 'ALS', 'N99.01'),
#  (22213, 'Schisis', 'D81'),
#  (11909, 'Verzakking', 'X17; X87'),
#  (17728, 'Zorg voor en na operaties', 'A87'),
#  (17890, 'Amputatie van een been', 'L14, L29'),
#  (19207, 'Polyneuropathie', 'n94'),
#  (14819, 'Schade aan de ogen bij diabetes', 'F83'),
#  (12430, 'Erythrasma', 'S76.02'),
#  (11514, 'Ziekte van Lyme', 'S12, A78.05'),
#  (11582, 'Teek', 'S12, A78'),
#  (11487, 'Schimmelnagels', 'S74.02'),
#  (11440, 'Verkouden', 'R74.01, R83'),
#  (20178, 'Longschade bij een te vroeg geboren baby', 'A93'),
#  (11763, 'Pijn in de nek', 'L01'),
#  (11745, 'Winterhanden en wintertenen', 'A88'),
#  (11747, 'Fenomeen van Raynaud', 'K92.02'),
#  (14235, 'Zenuwontsteking in de schouder', 'L99, n94'),
#  (12678, 'Nekhernia', 'L83.01'),
#  (11835, 'Slijmbeursontsteking elleboog', 'L99'),
#  (11584, 'Tennisarm', 'L93, L99'),
#  (11529, 'Spierreuma', 'L99'),
#  (13091, 'Bacteriële gewrichtsontsteking', 'L70'),
#  (11913, 'Fibromyalgie', 'L18.1'),
#  (11127, 'Diarree', 'D11'),
#  (11735, 'Adrenogenitaal syndroom', 'T99'),
#  (25614, 'Zwanger 41 weken', 'W78; W90; W92'),
#  (15491, 'Zwanger en de GBS bacterie', 'A94'),
#  (21540, 'Zwanger en hoge bloeddruk', 'W18, W81'),
#  (16086, 'Veel bloedverlies bij de bevalling', 'W90, W90;W29'),
#  (14758, 'Oogafwijking bij te vroeg geboren baby', 'F81'),
#  (23813, 'Kanker en zwanger worden', 'W72'),
#  (17682, 'Cyste op de eierstok', 'X99.03'),
#  (17840, 'Omgaan met pijn tijdens de bevalling', 'W90, W29'),
#  (11160, 'Nog niet zwanger geworden', 'W15, T99'),
#  (11305, 'Brandwonden', 'S14'),
#  (12621, 'Actinische keratose', 'S99'),
#  (11606, 'Reisziekte', 'A88.03'),
#  (13509, 'Zonneallergie', 'S88.04'),
#  (12280, 'Uitdroging', 'T11'),
#  (11197, 'Coeliakie', 'D99.06'),
#  (17546, 'Ontstoken voorhuid', 'Y04, y81'),
#  (11341, 'Ganglion', 'L87'),
#  (11337, 'Triggervinger', 'L99.04, L87'),
#  (11541, 'Peesirritatie van De Quervain', 'L87, L99'),
#  (11339, 'Malletvinger', 'L98.01'),
#  (11343, 'Carpaletunnelsyndroom', 'N93, L1'),
#  (24292, 'Behandelingen van de baarmoederhals', 'X85'),
#  (12262, 'Baarmoederhalskanker', 'X75'),
#  (22567, 'Schaamlipkanker', 'X25, x77'),
#  (14046, 'Speekselsteen', 'D83'),
#  (20286, 'Hoofd-/halsparagangliomen', 'S05, T78'),
#  (11167, 'Wormen', 'D22'),
#  (14826, 'Wormpjes', 'D22'),
#  (11504, 'Ziekte op reis voorkomen', 'D13'),
#  (11554, 'Knokkelkoorts', 'A88.03, A78, A77'),
#  (11870, 'Prostaatkanker', 'Y85, Y77, Y26, Y06'),
#  (11942, 'Zwemmersjeuk', 's02'),
#  (11140, 'Overgeven', 'D10;D09'),
#  (12180, 'Difterie', 'R83.01'),
#  (11652, 'Zesde ziekte', 'A76.01'),
#  (12312, 'Ziek van besmet eten', 'Z02'),
#  (11694, 'Buikgriep', 'D70; D73'),
#  (11452,
#   'Ontsteking in baarmoeder, eileider of eierstok',
#   'X74, X71, X84, X85, W15'),
#  (11333, 'Trichomonas', 'Y99, X73'),
#  (26072, 'Te veel normale bacteriën in vagina', 'X84'),
#  (11352, 'Chlamydia', 'X84.01, X85.01, X74.01, Y99.03'),
#  (11356, 'Gonorroe', 'Y71, X71'),
#  (11349,
#   'Soa',
#   'Y99, Y25, X99, X23, X84, X85, X92, X73, X70, Y71, Y76, Y70, Y72, X90, B90, X91, D72'),
#  (12591, 'Licht gevoel in het hoofd', 'H82, n17'),
#  (11410, 'Posttraumatische stressstoornis', 'P02.01'),
#  (18656, 'Overgevoelig voor melk', 'T99'),
#  (12605, 'Pijn bij ingang vagina', 'P08.02'),
#  (24932, 'Ontsteking baarmoeder-slijmvlies na bevalling', 'W70'),
#  (24904, "Baby's en huilen", 'A15'),
#  (26594, 'Nare bevalling', 'P02, W90, W91, W92, W93'),
#  (11215, 'Bevalling en erna', 'W90, W29'),
#  (11612, 'Spruw', 'S75'),
#  (23877, "Spugen bij baby's", 'T04, D84'),
#  (12604, 'Ontsteking van de gehoorgang', 'H70'),
#  (12375, 'Slokdarmkanker', 'D77'),
#  (12611, 'Vetlever', 'D97'),
#  (12620, 'Maagkanker', 'D74'),
#  (12661, 'Essentiële tremor', 'N06.01'),
#  (19289, 'Zwanger worden en erfelijke ziektes', 'A99'),
#  (23203, 'Te dikke hartspier', 'K84'),
#  (15871, 'Erfelijke ziekte', 'A99.01, A99.02'),
#  (18914, 'Dwarslaesie', 'L76, N81'),
#  (18990, 'Gebroken wervel', 'L76, N81'),
#  (11316, 'Dementie', 'P70'),
#  (20924, 'Nierkanker', 'U75'),
#  (23895, 'Asbestkanker in het longvlies of buikvlies', 'R85'),
#  (12038, 'Longkanker', 'R84'),
#  (14821, 'Vermoeidheid bij kanker die niet meer te genezen is', 'A04, A69.01'),
#  (18984, 'Kanker en werk', 'Z05'),
#  (11984, 'IJzerstapeling', 'T99'),
#  (12064, 'Hees', 'R23'),
#  (12075, 'Rouw', 'P03, P02'),
#  (12610, 'Minder zin in seks', 'P07'),
#  (13631, 'Bezoek aan de huisarts', 'A29, A97'),
#  (26876, 'Cholesteatoom', 'H74'),
#  (11100, 'Ontstoken bloedvat aan de zijkant van het hoofd', 'K99'),
#  (12205, 'Migraine', 'N89'),
#  (12612, 'Seks', 'Z12, Y24, Y07, Y01, P08, P07'),
#  (12606, 'Snel klaarkomen', 'P08.03'),
#  (26610, 'Seks met jezelf', 'P08, P07'),
#  (12138, 'Ziekte van Peyronie', 'Y99'),
#  (14929, 'Groep A streptokok', 'S76, R72'),
#  (11187, 'Waterpokken', 'A72'),
#  (12349, 'Bedwantsen', 'S12'),
#  (12634, 'Malaria', 'A73'),
#  (12264, 'Zikakoorts', 'A77'),
#  (11224, 'Hepatitis A', 'D72'),
#  (12247, 'Leverontsteking', 'D72'),
#  (14077, 'Hondsdolheid', 'S13, A77'),
#  (12175, 'Chikungunya', 'A88.03, A78, A77'),
#  (11228, 'Hepatitis B', 'D72'),
#  (22731, 'Hersenschade en werk', 'N79, n29'),
#  (12479, 'Vernauwing van de halsslagader', 'K91, K90'),
#  (11620, 'Ziekte van Ménière', 'H82.01'),
#  (12590, 'Draai-duizeligheid', 'n17'),
#  (12626, 'Aanvallen van duizeligheid bij of na migraine', 'N89, n17'),
#  (26642, 'Speciale oefeningen tegen duizeligheid', 'H82'),
#  (11624, 'Neuritis vestibularis', 'H82, n17'),
#  (11622, 'Positie-duizeligheid (BPPD)', 'H82.03;N17'),
#  (11454, 'Oorsuizen', 'H03'),
#  (12436, 'Erg ontstoken vinger (fijt)', 'S09.02'),
#  (12438, 'Ontstoken nagelriem', 's09'),
#  (11358, 'Hiv', 'B90'),
#  (11724, 'Schurft', 'S72.01'),
#  (17088, 'DCD', 'p24'),
#  (12514, 'ARFID', 'T04, T05'),
#  (11362, 'Syfilis', 'Y70, X70'),
#  (11354, 'Wratten op penis, vagina of anus', 'Y76, X91'),
#  (19987, 'Zenuwen klem in buikwand', 'D06'),
#  (11997, 'Blindedarmontsteking', 'D88'),
#  (12527, 'Verwijde buikslagader', 'K99'),
#  (20029, 'Ontsteking van de slokdarm door maagzuur', 'D84.03'),
#  (11290, 'Bloedneus', 'R06'),
#  (11195, 'Bijholteontsteking', 'r75'),
#  (13719, 'Heupontsteking bij kinderen', 'L99'),
#  (12440, 'Putjeszolen', 'S76'),
#  (26084, 'Dichte zaadleiders', 'Y10; A97.02'),
#  (12223, 'Hersenvlies-ontsteking', 'N71'),
#  (11666, 'Koorts bij kinderen', 'A03'),
#  (11085, 'Aangezichtsverlamming van Bell', 'N91; N18; N19'),
#  (24914, 'Borstontsteking bij borstvoeding', 'W94, W20'),
#  (26402, 'Problemen met poepen bij kinderen', 'D12'),
#  (12622, 'Lawaaidoofheid', 'H85'),
#  (12421, 'Keratoacanthoom', 'S99'),
#  (12624, 'Huidziekte van Bowen', 'S77'),
#  (22273, 'Gebroken pols', 'L72'),
#  (11419, 'Smetplekken', 'S74'),
#  (11662, 'Huidschimmel', 'S74'),
#  (11347, 'Herpes genitalis', 'X90;Y72'),
#  (11360, 'Schaamluis', 'S73.02'),
#  (11733, 'MS', 'N86'),
#  (26020,
#   'Stoppen met medicijnen tegen problemen met plassen',
#   'U02; U05; U04; U07'),
#  (25442, 'Bedplassen bij kinderen', 'P12'),
#  (12627, 'Kaalheid bij vrouwen', 'S23'),
#  (12628, 'Kaalheid bij mannen', 'S23'),
#  (11795, 'Haaruitval', 'S23'),
#  (12629, 'Kale plekken', 'S23'),
#  (11828, 'Liesbreuk', 'D89'),
#  (23791, 'Kind weegt te weinig', 'T91, p11'),
#  (26328, 'Eten zit vast in keel of slokdarm kind', 'D21, D79'),
#  (26292, 'Voorwerp inslikken', 'D21, D79'),
#  (11637, 'Kinderziekten met vlekjes', 'A76.02, A76.01, A74, A72, A71'),
#  (11657, 'Roodvonk', 'R72'),
#  (14251, 'Leverschade', 'D97'),
#  (11232, 'Hepatitis C', 'D72'),
#  (11445, 'Voetschimmel', 'S74.01'),
#  (11163, 'Krentenbaard', 'S84'),
#  (11136, 'Luieruitslag', 'S75, S89'),
#  (11461, 'Zomergist', 'S74.03'),
#  (18570, 'Maagzweer', 'D85;D86'),
#  (25848, 'Gevaarlijke stof in oog', 'F79'),
#  (23071, 'Berg', 'S86'),
#  (12276, 'RS-virus', 'A77'),
#  (11645, 'Rodehond', 'A74'),
#  (11660, 'Longontsteking', 'R81'),
#  (11767, 'Hand-voet-mondziekte', 'A77'),
#  (11641, 'Mazelen', 'A71'),
#  (11743, 'Bof', 'D71'),
#  (22104, 'Delier bij kinderen', 'P71'),
#  (11424, 'Loopoor', 'H72, H71'),
#  (12602, 'Trommelvlies-buisjes', 'H71, H72, H74'),
#  (22975, 'Hangende oogleden of wenkbrauwen', 'F16'),
#  (21748, 'Clusterhoofdpijn', 'N90'),
#  (24650, 'Mycoplasma', 'X99'),
#  (13767, 'Aften', 'D83'),
#  (11614, 'Tanden verzorgen', 'D83, D82, D19, D20, S71'),
#  (11759, 'Kapotte mondhoeken', 'D83.3'),
#  (11757, 'Hielspoor', 'L99'),
#  (11598, 'Hik', 'R29'),
#  (23735, 'Bloedvat-toegang voor dialyse', 'U99'),
#  (12059, 'Plotselinge doofheid', 'H86'),
#  (11773, 'Narcolepsie', 'N99'),
#  (11718, 'Navelbreuk', 'D91.02'),
#  (11771, 'Myasthenia gravis', 'N99.02'),
#  (16012, 'Pijn in de balzak', 'Y99, Y74, Y02'),
#  (11714, 'Morton neuroom', 'N94.6'),
#  (12106, 'Schoenen en uw voeten', 'L17.01'),
#  (11787, 'Osteogenesis imperfecta', 'L82'),
#  (11722, 'Lage bloeddruk', 'K29'),
#  (16644, 'Netvliesloslating', 'F82'),
#  (11707, 'Medicijnen en veilig rijden', 'A13'),
#  (12377, 'Ontsteking van de binnenkant van het hart', 'K83, K73, K71'),
#  (17638, 'Elleboog uit de kom', 'L80'),
#  (11093, 'Antibiotica', 'A97'),
#  (14713, 'Bacteriën die ongevoelig zijn voor antibiotica', 'A97'),
#  (11465, 'Roos', 'S86'),
#  (11647, 'Hoofdschimmel', 'S74'),
#  (11680, 'Luizen op het hoofd', 'S73.01'),
#  (16922, 'Ooginfarct', 'K99, F94, K91'),
#  (11635, 'Kinkhoest', 'R71'),
#  (21752, 'Melasma', 'S82, S79'),
#  (11739, 'Diabetes insipidus', 'T99'),
#  (16712, 'Opticusatrofie', 'N81, F99'),
#  (11818, 'Syndroom van Tietze', 'L99.06'),
#  (12812, 'Spierziekte Duchenne', 'N99'),
#  (12356, 'Hallux valgus', 'L98.03'),
#  (11775, 'Stofwisselingsziekten', 'T99'),
#  (11765, 'Galstenen', 'D98.01, D98.02, D98.03'),
#  (11741, 'Homocystinurie', 'T99.04'),
#  (11711, 'Zweepslag in de kuit', 'L81.01'),
#  (12337, 'Heftige pijn in de balzak', 'Y99.01'),
#  (16246, 'Verdoving bij oogoperaties', 'F01, F29'),
#  (12101, 'Klaplong', 'R99'),
#  (24078, 'Lichen planus', 'S99'),
#  (11809, 'Pityriasis rosea', 'S90'),
#  (11783, 'Ziekte van Paget', 'L99'),
#  (22377, 'Downsyndroom', 'A90'),
#  (16796, 'Trombose in het oog', 'K94, F94'),
#  (12081, 'Dikkere borsten bij mannen', 'Y29.01'),
#  (15705, 'Overgevoelig voor contrastmiddel', 'A12, A85')]

# %%
multiple_icpc = []
for i in range(len(df)):
    if df['icpc'][i] is not None:
        if ',' in df['icpc'][i]:
            multiple_icpc.append((df['id'][i], df['subject_title'][i], df['icpc'][i]))

print(f'Number of subjects with multiple ICPC codes: {len(multiple_icpc)}')
# Out:
# Number of subjects with multiple ICPC codes: 173

# %%
multiple_icpc
# Out:
# [(11923, 'Eetprobleem', 'T05, T06'),
#  (11098, 'Depressie', 'P03, P77, P76'),
#  (11429, 'Lange tijd of vaak neusklachten', 'R97, R07'),
#  (24130, 'Naaste met corona', 'R83.03, Z22'),
#  (11916, 'Darmkanker', 'D16, D75'),
#  (11102, 'Artrose', 'L91, L90, L89, L84, L20'),
#  (11221, 'Knieklachten', 'L99, L94, L90, L15, L78, L96'),
#  (26412, 'Overgewicht bij kinderen', 'T83, T82'),
#  (11630, 'Gezond leven', 'P17, T5, T83, T91'),
#  (11387, 'Keelpijn', 'r76, R72, R21.01'),
#  (11261, 'Reumatoïde artritis', 'N93, L88'),
#  (12462, 'Kunstheup', 'L89, L75, L13'),
#  (11181, 'Hartaanval', 'K76, K75, K74'),
#  (28299, 'Werk en privé-leven', 'Z05, Z29'),
#  (11968,
#   'Communicatie, hoorproblemen en verstandelijke beperkingen',
#   'P85, H86'),
#  (11467, 'Slecht horen', 'H02, H84, H86'),
#  (11294, 'Borstkanker opsporen', 'X26, X76, A97'),
#  (11345, 'Ziekte van Dupuytren', 'L99.03, L87'),
#  (21070, 'Plekje op de huid', 'S99, S77'),
#  (11639, 'Moedervlekken', 'S82, S77'),
#  (26410, 'Overgewicht bij volwassenen', 'T83, T82'),
#  (12471, 'Keizersnede', 'W92, W78'),
#  (12230,
#   'Psychische klachten bij volwassenen',
#   'P99, P76, P74, P73, P72, P29, P02'),
#  (11955, 'Eikenprocessierups', 's02, A88'),
#  (11397, 'Risico hart- en vaatziekten verlagen', 'K49.01, K75, K91'),
#  (12387, 'Seksueel geweld', 'Z25.01, Z12'),
#  (22143, 'Dissociatieve stoornis', 'P79, P99'),
#  (12267, 'Problemen thuis', 'P04, P22, P23, Z12, Z16'),
#  (12086, 'Functioneel-neurologische stoornis', 'P99, P75'),
#  (12922, 'Eetstoornis', 'p11, T06'),
#  (11675, 'Moeheid', 'Z29, P06, B80, A04'),
#  (12607, 'Depressie na de bevalling', 'p76.01, P76'),
#  (11686, 'Nierschade', 'U99, U98'),
#  (11479, 'Schildklier-problemen', 'T86, T85, A91'),
#  (12636, 'Te snel werkende schildklier', 'T85, A91'),
#  (22521, 'Zwanger van een drieling', 'W78, W84'),
#  (14527, 'Zwanger, misselijk en overgeven', 'D09, W05'),
#  (14113, 'Zwanger en jeuk', 's02, W29'),
#  (14372, 'Zwanger van een tweeling', 'W78, W84'),
#  (12215, 'Sarcoïdose', 'R83, R05'),
#  (25058, 'Reuma-medicijnen en zwanger', 'L88, W78'),
#  (28584, 'Veel te zwaar en zwanger', 'T82, W78'),
#  (12185, 'Zenuwpijn', 's01, n94, n92, n29, N03'),
#  (12609, 'Seksuele klachten vrouwen', 'P07, P08'),
#  (11684, 'Endometriose', 'X99, X02'),
#  (21474, 'Kunst-schouder', 'L08, L91'),
#  (11508, 'Minder goed zien bij kinderen', 'F91, F05'),
#  (12196, 'Minder goed zien bij volwassenen', 'F05, F91'),
#  (11199, 'Boezem-fibrilleren', 'K78, K04'),
#  (11298, 'COPD', 'R95, R91, R02'),
#  (12581, 'Retinitis pigmentosa', 'F83, F94'),
#  (12201, 'Glasvochtloslating', 'F99, F04'),
#  (11274, 'Maagklachten', 'D87, D03, D02, A49'),
#  (11148, 'Steenpuist', 'R73, S10'),
#  (15983, 'Prikpil', 'W14, W11'),
#  (12285, 'Bronchitis', 'R78, R05'),
#  (23251, 'Drugs', 'P19, Z13, Z21'),
#  (12608, 'Ontstoken slijmbeurs in de knie', 'L99.01, L70, L15'),
#  (15797, 'Knieschijf uit de kom', 'L15, L80'),
#  (11552, 'Springersknie', 'l99.02, L15'),
#  (12615, 'Lopersknie', 'L15, L99'),
#  (11495, 'Verzwikte enkel', 'L77, L16'),
#  (11539, 'Pijn aan de knieschijf bij bewegen', 'L15, L99'),
#  (11672, 'Buikpijn', 'D01, D02, D06, D08, D12, D73, D87'),
#  (12283, 'Verstopte traanbuis', 'F80, F73'),
#  (11628, 'Hard bultje in het ooglid dat geen pijn doet', 'F72, F13, F02'),
#  (12997,
#   'Psychische klachten als je jong bent',
#   'p24, P99, P21, p11, P22, P29'),
#  (11709, 'Medicijnen bij ouderen', 'A13, A49'),
#  (11580, 'Spataderen', 'w77, K95'),
#  (12227, 'Gekneusde of gebroken rib', 'L81.02, L76.05'),
#  (11154, 'Koortsstuip', 'N07, A03'),
#  (12021, 'Pijn op de borst', 'R01, K01, L04'),
#  (11547, 'Psychosociale problemen', 'Z29, Z04, P29'),
#  (12069, 'Stress', 'P01, P02'),
#  (12595, 'Astma bij kinderen', 'R96, R02'),
#  (11256, 'Astma bij volwassenen', 'R96, R02'),
#  (12057, 'Snurken', 'R06, r04'),
#  (14189, 'DNA-onderzoek bij medicijnen', 'A13, A84, A85'),
#  (11267, 'Hoge bloeddruk', 'K86, K87'),
#  (11079, 'Beroerte', 'K90, K89'),
#  (11171, 'Zwanger worden', 'A97, W15, Y10'),
#  (11253, 'Penis minder stijf', 'P08, Y07'),
#  (19807, 'Zwakke plek in een bloedvat in het hoofd', 'K90, K99'),
#  (12617, 'Chronische pijn', 'A85, A01'),
#  (11205, 'Bloedarmoede', 'B80, B81, B82'),
#  (24252, 'Gezond eten', 'T05, T91'),
#  (12637, 'Ontsteking door schimmel in de vagina', 'X14, X72'),
#  (11230, 'Uitstrijkje baarmoederhals', 'X85, X86, A97'),
#  (11309, 'Blaasontsteking', 'U71, U29'),
#  (12666, 'Problemen met plassen bij vrouwen', 'U04, U29, U71'),
#  (12217, 'Sepsis', 'A03, a02'),
#  (11477, 'Slijm of pus uit penis', 'Y71, Y03, U72, Y99.03'),
#  (11929, 'Blaasontsteking bij kinderen', 'U71, U29'),
#  (11833, 'Buikpijn bij kinderen', 'D87, D73, D12, D08, D06, D02, D01'),
#  (11866, 'Problemen met plassen bij mannen', 'u02, U04, U05, Y85'),
#  (12147, 'Overactieve blaas', 'U04.02, U04, u02'),
#  (11831, 'Lichen sclerosus', 's02, D05, Y04, S02;D05;Y04;X16, S99'),
#  (11678, 'Scheurtjes in de anus (poepgat)', 'D04, D16, D95'),
#  (11590, 'Mondproblemen', 'D83, D82, D19, D20, S71'),
#  (12603, 'Middenoor-ontsteking', 'H01, H71, H72, H74'),
#  (12601, 'Oorpijn', 'H71, H70'),
#  (12141, 'Val of klap op het hoofd', 'N80, N79, A80'),
#  (12394, 'Wonden', 'S14, S17, S18, S19'),
#  (12587, 'Spiraaltje', 'W12, W10'),
#  (11113, 'Zwangerschap voorkomen', 'W11, W10, W12, W14, S96'),
#  (13995, 'Kalmeringsmiddelen', 'P01, P74'),
#  (12638, 'Morning-afterpil', 'W10, W12'),
#  (12092, 'Onbedoeld zwanger', 'w83, w79'),
#  (11682, 'Onderzoek baby in de buik', 'A97, A99'),
#  (21952, 'Pijn bij kanker', 'A87, A01'),
#  (17890, 'Amputatie van een been', 'L14, L29'),
#  (11514, 'Ziekte van Lyme', 'S12, A78.05'),
#  (11582, 'Teek', 'S12, A78'),
#  (11440, 'Verkouden', 'R74.01, R83'),
#  (14235, 'Zenuwontsteking in de schouder', 'L99, n94'),
#  (11584, 'Tennisarm', 'L93, L99'),
#  (21540, 'Zwanger en hoge bloeddruk', 'W18, W81'),
#  (16086, 'Veel bloedverlies bij de bevalling', 'W90, W90;W29'),
#  (17840, 'Omgaan met pijn tijdens de bevalling', 'W90, W29'),
#  (11160, 'Nog niet zwanger geworden', 'W15, T99'),
#  (17546, 'Ontstoken voorhuid', 'Y04, y81'),
#  (11337, 'Triggervinger', 'L99.04, L87'),
#  (11541, 'Peesirritatie van De Quervain', 'L87, L99'),
#  (11343, 'Carpaletunnelsyndroom', 'N93, L1'),
#  (22567, 'Schaamlipkanker', 'X25, x77'),
#  (20286, 'Hoofd-/halsparagangliomen', 'S05, T78'),
#  (11554, 'Knokkelkoorts', 'A88.03, A78, A77'),
#  (11870, 'Prostaatkanker', 'Y85, Y77, Y26, Y06'),
#  (11452,
#   'Ontsteking in baarmoeder, eileider of eierstok',
#   'X74, X71, X84, X85, W15'),
#  (11333, 'Trichomonas', 'Y99, X73'),
#  (11352, 'Chlamydia', 'X84.01, X85.01, X74.01, Y99.03'),
#  (11356, 'Gonorroe', 'Y71, X71'),
#  (11349,
#   'Soa',
#   'Y99, Y25, X99, X23, X84, X85, X92, X73, X70, Y71, Y76, Y70, Y72, X90, B90, X91, D72'),
#  (12591, 'Licht gevoel in het hoofd', 'H82, n17'),
#  (26594, 'Nare bevalling', 'P02, W90, W91, W92, W93'),
#  (11215, 'Bevalling en erna', 'W90, W29'),
#  (23877, "Spugen bij baby's", 'T04, D84'),
#  (15871, 'Erfelijke ziekte', 'A99.01, A99.02'),
#  (18914, 'Dwarslaesie', 'L76, N81'),
#  (18990, 'Gebroken wervel', 'L76, N81'),
#  (14821, 'Vermoeidheid bij kanker die niet meer te genezen is', 'A04, A69.01'),
#  (12075, 'Rouw', 'P03, P02'),
#  (13631, 'Bezoek aan de huisarts', 'A29, A97'),
#  (12612, 'Seks', 'Z12, Y24, Y07, Y01, P08, P07'),
#  (26610, 'Seks met jezelf', 'P08, P07'),
#  (14929, 'Groep A streptokok', 'S76, R72'),
#  (14077, 'Hondsdolheid', 'S13, A77'),
#  (12175, 'Chikungunya', 'A88.03, A78, A77'),
#  (22731, 'Hersenschade en werk', 'N79, n29'),
#  (12479, 'Vernauwing van de halsslagader', 'K91, K90'),
#  (12626, 'Aanvallen van duizeligheid bij of na migraine', 'N89, n17'),
#  (11624, 'Neuritis vestibularis', 'H82, n17'),
#  (12514, 'ARFID', 'T04, T05'),
#  (11362, 'Syfilis', 'Y70, X70'),
#  (11354, 'Wratten op penis, vagina of anus', 'Y76, X91'),
#  (24914, 'Borstontsteking bij borstvoeding', 'W94, W20'),
#  (23791, 'Kind weegt te weinig', 'T91, p11'),
#  (26328, 'Eten zit vast in keel of slokdarm kind', 'D21, D79'),
#  (26292, 'Voorwerp inslikken', 'D21, D79'),
#  (11637, 'Kinderziekten met vlekjes', 'A76.02, A76.01, A74, A72, A71'),
#  (11136, 'Luieruitslag', 'S75, S89'),
#  (11424, 'Loopoor', 'H72, H71'),
#  (12602, 'Trommelvlies-buisjes', 'H71, H72, H74'),
#  (11614, 'Tanden verzorgen', 'D83, D82, D19, D20, S71'),
#  (16012, 'Pijn in de balzak', 'Y99, Y74, Y02'),
#  (12377, 'Ontsteking van de binnenkant van het hart', 'K83, K73, K71'),
#  (16922, 'Ooginfarct', 'K99, F94, K91'),
#  (21752, 'Melasma', 'S82, S79'),
#  (16712, 'Opticusatrofie', 'N81, F99'),
#  (11765, 'Galstenen', 'D98.01, D98.02, D98.03'),
#  (16246, 'Verdoving bij oogoperaties', 'F01, F29'),
#  (16796, 'Trombose in het oog', 'K94, F94'),
#  (15705, 'Overgevoelig voor contrastmiddel', 'A12, A85')]

# %%
df['icpc'].value_counts()
print(f'There are {len(df["icpc"].value_counts())} unique ICPC codes')
# Out:
# There are 494 unique ICPC codes

# %% [markdown]
# #### Exploration of subjects and synonyms

# %%
no_synonyms= []
synonyms_present = []

for i in range(len(df)):
    if df['synonyms'][i] is None:
        no_synonyms.append((df['id'][i], df['subject_title'][i]))
    else:
        synonyms_present.append((df['id'][i], df['subject_title'][i], df['synonyms'][i]))

print(f'Number of subjects with no synonyms listed: {len(no_synonyms)}')
print(f'Number of subjects with listed synonyms: {len(synonyms_present)}')

# print("\nSubjects with no ICPC codes:")
# for subject_id, subject_title in no_icpc:
#     print(f'ID: {subject_id}, Title: {subject_title}')
# Out:
# Number of subjects with no synonyms listed: 128
# Number of subjects with listed synonyms: 512

# %%
synonyms_no_icpc = []
for i in range(len(df)):
    if df['synonyms'][i] is not None and df['icpc'][i] is None:
        synonyms_no_icpc.append((df['id'][i], df['subject_title'][i], df['synonyms'][i]))

print(f'Number of subjects with synonyms but no ICPC codes: {len(synonyms_no_icpc)}')
synonyms_no_icpc
# Out:
# Number of subjects with synonyms but no ICPC codes: 36
# [(22397, 'PEG-sonde', 'Gastrostomie-katheter'),
#  (11150, 'Bloed uit de vagina', 'ongesteld, menstruatie'),
#  (26987, 'Nadenken over je leven', 'Zingeving, spiritualiteit, levensvragen'),
#  (25746,
#   'Psychische klachten en werk',
#   'Re-integratie bij psychische klachten'),
#  (12635, 'Te langzaam werkende schildklier', 'Hypothyreoïdie, Hashimoto'),
#  (21360, 'Kijkoperatie van de knie', 'Artroscopie'),
#  (12642,
#   'Pijnstillers zoals ibuprofen, naproxen en diclofenac (NSAID)',
#   'Ontstekingsremmer'),
#  (20507, "Röntgenfoto's", 'Röntgenonderzoek'),
#  (17228, 'MRI', 'Magnetic Resonance Imaging'),
#  (11664, 'Vitamine D', 'Ergocalciferol, Colecalciferol, D'),
#  (12016, 'Ziekte van Scheuermann', 'Scheuermann, Juveniele kyfose'),
#  (21410, 'Pijn onder in buik en in bekken', 'Chronische bekkenpijn'),
#  (12588, 'Sterilisatie bij de vrouw', 'Eileiders afsluiten'),
#  (12584, 'Hormoonring', 'Vaginale ring, anticonceptie-ring'),
#  (19449, 'Echo', 'Echografie'),
#  (27403,
#   'Hoge druk in de hersenen',
#   'idiopathische intracraniële hypertensie'),
#  (23875, 'Uitzaaiingen in de hersenen', 'Hersenmetastasen'),
#  (11816, 'Golfarm', 'Golfelleboog, epicondylitis medialis'),
#  (11698, 'Groei kind', 'Lengtegroei'),
#  (26726,
#   'Minder goed zien bij kinderen door hersenschade voor of rond de geboorte',
#   'CVI, cerebral visual impairment, cerebrale visusstoornis, cerebraal visuele stoornis'),
#  (11592, 'Hoogteziekte', 'Bergziekte, Alpenziekte'),
#  (12600,
#   'Gescheurd trommelvlies',
#   'Trommelvlies gescheurd, trommelvliesperforatie'),
#  (11705, 'Koorts', 'Verhoogde lichaamstemperatuur, Verhoging'),
#  (11720,
#   'Aangezichtspijn',
#   'Trigeminusneuralgie, Pijn in het gezicht, Gezichtspijn'),
#  (24732, 'Mastocytose', 'Mestcel-ziekte'),
#  (12639, 'Onderzoeken van het hart', 'Hartonderzoeken, Onderzoek hart'),
#  (24166, 'Apenpokken', 'Mpox'),
#  (21594,
#   'Kind stopt even met ademen',
#   'BRUE, Brief Resolved Unexplained Event'),
#  (11189, 'Vijfde ziekte', 'Erythema infectiosum'),
#  (12090, 'Ebola', 'Ebola hemorragische koorts, Filovirus, Ebolavirus'),
#  (11616,
#   'Verstopt oor',
#   'Cerumenprop, Oorsmeer, Oor laten uitspuiten, Uitspuiten oor, Prop in het oor'),
#  (11751, 'Ingegroeide teennagel', 'Unguis incarnatus, Teennagel ingegroeid'),
#  (17428, 'Te vroeg gesloten schedelnaden', 'Craniosynostose'),
#  (16900, 'Vochtblaasje in het netvlies', 'retinitis centralis serosa, RCS'),
#  (12135, 'Vogelgriep', 'Vogelpest, Aviaire influenza'),
#  (12014, 'Bloed ophoesten', 'Hemoptoë')]

# %%
#extract title and summary  from each subject and store in a list
docs = []
for subject in subjects:
    doc = subject['title'] + '. ' + subject['summary']
    docs.append(doc)

html_pattern = re.compile(r'<[^>]+>')
escape_pattern = re.compile(r'\\u[0-9a-fA-F]{4}')
newline_pattern = re.compile(r'(\n|\t|\xa0|\u202f)')


clean_text = [newline_pattern.sub(' ', escape_pattern.sub(' ', html_pattern.sub(' ', item))) for item in docs]

clean_text = [item.strip() for item in clean_text]

# %%
nlp = sp.load('nl_core_news_sm')
for i in range(0,len(subjects)-1):
    doc = nlp(clean_text[i])
    for token in doc:
        print(token.text, token.pos_, token.dep_)

    #delete prepositions and stop words, and punctuation and lemmatize tokens (to get canonical form)
    lemmas = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct and not token.pos_ == 'ADP']
    print(lemmas)
    #give me all adjacent pairs of words
    pairs = []
    for i in range(len(lemmas)-1):
        pairs.append((lemmas[i], lemmas[i+1]))
    print(pairs)
# Out:
# Ziekte NOUN ROOT
# van ADP case
# Parkinson PROPN nmod
# . PUNCT punct
#    SPACE dep
# Bij ADP case
# de DET det
# ziekte NOUN obl
# van ADP case
# Parkinson PROPN nmod
# krijg VERB ROOT
# je PRON nsubj
# problemen NOUN obj
# met ADP case
# bewegen NOUN nmod
# . PUNCT punct
#     SPACE dep
# Ook ADV advmod
# bijvoorbeeld ADV advmod
# denken VERB advcl
# , PUNCT punct
# slikken VERB conj
# en CCONJ cc
# slapen VERB conj
# gaan VERB ROOT
# vaak ADJ advmod
# moeilijker ADJ advmod
# . PUNCT punct
#     SPACE dep
# Medicijnen NOUN nsubj
# kunnen AUX aux
# ervoor ADV advmod
# zorgen VERB ROOT
# dat SCONJ mark
# je PRON nsubj
# minder DET advmod
# stijf NOUN ccomp
# bent AUX cop
# en CCONJ cc
# minder PRON advmod
# trilt VERB conj
# . PUNCT punct
#     SPACE dep
# Beweeg ADP case
# elke DET det
# dag NOUN obl
# minstens ADV amod
# een DET det
# half ADJ amod
# uur NOUN ROOT
# . PUNCT punct
#     SPACE dep
# Maak VERB ROOT
# je PRON nmod:poss
# huis NOUN obj
# veilig ADJ xcomp
# , PUNCT punct
# zodat SCONJ mark
# je PRON nsubj
# niet ADV advmod
# valt VERB parataxis
# . PUNCT punct
# ['ziekte', 'Parkinson', '  ', 'ziekte', 'Parkinson', 'krijgen', 'probleem', 'beweg', '   ', 'denken', 'slikken', 'slapen', 'gaan', 'moeilijk', '   ', 'medicijn', 'ervoor', 'zorgen', 'stijf', 'trillen', '   ', 'dag', 'minstens', 'half', 'uur', '   ', 'moaken', 'huis', 'veilig', 'zodat', 'vallen']
# [('ziekte', 'Parkinson'), ('Parkinson', '  '), ('  ', 'ziekte'), ('ziekte', 'Parkinson'), ('Parkinson', 'krijgen'), ('krijgen', 'probleem'), ('probleem', 'beweg'), ('beweg', '   '), ('   ', 'denken'), ('denken', 'slikken'), ('slikken', 'slapen'), ('slapen', 'gaan'), ('gaan', 'moeilijk'), ('moeilijk', '   '), ('   ', 'medicijn'), ('medicijn', 'ervoor'), ('ervoor', 'zorgen'), ('zorgen', 'stijf'), ('stijf', 'trillen'), ('trillen', '   '), ('   ', 'dag'), ('dag', 'minstens'), ('minstens', 'half'), ('half', 'uur'), ('uur', '   '), ('   ', 'moaken'), ('moaken', 'huis'), ('huis', 'veilig'), ('veilig', 'zodat'), ('zodat', 'vallen')]
# Zwanger NOUN ROOT
# en CCONJ cc
# corona PROPN conj
# . PUNCT punct
#    SPACE dep
# Als SCONJ mark
# je PRON nsubj
# zwanger NOUN obl
# bent AUX cop
# krijg VERB parataxis
# je PRON nsubj
# , PUNCT punct
# voor ADP mark
# zover ADV fixed
# nu ADV advmod
# bekend ADJ xcomp
# , PUNCT punct
# niet ADV advmod
# sneller ADJ ROOT
# het DET det
# coronavirus NOUN nsubj
# dan SCONJ mark
# anders ADV advcl
# . PUNCT punct
#     SPACE dep
# Als SCONJ mark
# je PRON nsubj
# zwanger ADJ advcl
# bent AUX cop
# , PUNCT punct
# is AUX cop
# de DET det
# kans NOUN nsubj
# iets PRON obl
# groter ADJ ROOT
# dat SCONJ mark
# je PRON nsubj
# erg ADJ advmod
# ziek ADJ xcomp
# wordt AUX ccomp
# door ADP case
# corona PROPN obl
# . PUNCT punct
#     SPACE dep
# Voor ADP mark
# zover ADV fixed
# nu ADV advmod
# bekend ADJ parataxis
# , PUNCT punct
# heb AUX ROOT
# je PRON nsubj
# met ADP case
# corona PROPN obl
# niet ADV advmod
# meer DET advmod
# kans NOUN obj
# op ADP case
# een DET det
# miskraam NOUN nmod
# . PUNCT punct
#     SPACE dep
# Corona ADV ROOT
# tijdens ADP case
# de DET det
# zwangerschap NOUN parataxis
# kan AUX parataxis
# , PUNCT punct
# met ADP case
# wat PRON obj
# we PRON nsubj
# nu ADV advmod
# weten VERB advcl
# , PUNCT punct
# geen DET det
# kwaad NOUN parataxis
# voor ADP case
# jouw PRON nmod:poss
# baby NOUN nmod
# . PUNCT punct
#     SPACE dep
# Ga VERB ROOT
# je PRON nsubj
# naar ADP case
# de DET det
# verloskundige ADJ obl
# of CCONJ cc
# arts NOUN conj
# en CCONJ cc
# denk VERB conj
# je PRON nsubj
# dat SCONJ mark
# je PRON nsubj
# misschien ADV advmod
# corona ADV obj
# hebt VERB ccomp
# ? PUNCT punct
# Bel PROPN ROOT
# dan ADV advmod
# eerst ADV advmod
# voordat SCONJ mark
# je PRON nsubj
# erheen ADJ obj
# gaat VERB advcl
# . PUNCT punct
#     SPACE dep
# Alle DET det
# zwangere ADJ amod
# vrouwen NOUN nsubj
# mogen VERB aux
# een DET det
# prik NOUN obj
# tegen ADP case
# corona PROPN obl
# halen VERB ROOT
# . PUNCT punct
# ['zwanger', 'corona', '  ', 'zwang', 'krijgen', 'zover', 'bekend', 'snel', 'coronavirus', '   ', 'zwang', 'kans', 'groot', 'erg', 'ziek', 'corona', '   ', 'zover', 'bekend', 'corona', 'kans', 'miskraam', '   ', 'Corona', 'zwangerschap', 'weten', 'kwaad', 'baby', '   ', 'Ga', 'verloskundig', 'arts', 'denken', 'corona', 'Bel', 'erheen', 'gaan', '   ', 'zwanger', 'vrouw', 'prik', 'corona', 'halen']
# [('zwanger', 'corona'), ('corona', '  '), ('  ', 'zwang'), ('zwang', 'krijgen'), ('krijgen', 'zover'), ('zover', 'bekend'), ('bekend', 'snel'), ('snel', 'coronavirus'), ('coronavirus', '   '), ('   ', 'zwang'), ('zwang', 'kans'), ('kans', 'groot'), ('groot', 'erg'), ('erg', 'ziek'), ('ziek', 'corona'), ('corona', '   '), ('   ', 'zover'), ('zover', 'bekend'), ('bekend', 'corona'), ('corona', 'kans'), ('kans', 'miskraam'), ('miskraam', '   '), ('   ', 'Corona'), ('Corona', 'zwangerschap'), ('zwangerschap', 'weten'), ('weten', 'kwaad'), ('kwaad', 'baby'), ('baby', '   '), ('   ', 'Ga'), ('Ga', 'verloskundig'), ('verloskundig', 'arts'), ('arts', 'denken'), ('denken', 'corona'), ('corona', 'Bel'), ('Bel', 'erheen'), ('erheen', 'gaan'), ('gaan', '   '), ('   ', 'zwanger'), ('zwanger', 'vrouw'), ('vrouw', 'prik'), ('prik', 'corona'), ('corona', 'halen')]
# Corona PROPN ROOT
# in ADP case
# het DET det
# ziekenhuis NOUN nmod
# . PUNCT punct
#    SPACE dep
# U PRON nsubj
# kunt AUX aux
# in ADP case
# het DET det
# ziekenhuis NOUN obl
# medicijnen VERB amod
# krijgen VERB ROOT
# : PUNCT punct
# tegen ADP case
# ontstekingen NOUN ROOT
# , PUNCT punct
# tegen ADP case
# bloedklonten NOUN conj
# ( PUNCT punct
# trombose NOUN nmod
# of CCONJ cc
# longembolie NOUN conj
# ) PUNCT punct
# en CCONJ cc
# tegen ADP case
# uw PRON nmod:poss
# klachten NOUN conj
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# extra ADJ amod
# zuurstof NOUN obj
# krijgen VERB ROOT
# . PUNCT punct
# Via ADP case
# een DET det
# slangetje NOUN ROOT
# in ADP case
# uw PRON nmod:poss
# neus NOUN nmod
# , PUNCT punct
# eventueel ADJ amod
# met ADP case
# een DET det
# speciaal ADJ amod
# apparaat NOUN obl
# of CCONJ cc
# via ADP case
# een DET det
# kapje NOUN conj
# op ADP case
# uw PRON nmod:poss
# gezicht NOUN nmod
# . PUNCT punct
#     SPACE dep
# Als SCONJ mark
# de DET det
# medicijnen NOUN nsubj
# en CCONJ cc
# extra ADJ amod
# zuurstof NOUN conj
# niet ADV advmod
# genoeg ADV advmod
# helpen VERB advcl
# , PUNCT punct
# kunt AUX aux
# u PRON nsubj
# beademd VERB ROOT
# worden AUX aux:pass
# op ADP case
# de DET det
# IC PROPN obl
# . PUNCT punct
#     SPACE dep
# Na ADP case
# een DET det
# opname NOUN obl
# in ADP case
# het DET det
# ziekenhuis NOUN nmod
# duurt VERB ROOT
# het PRON expl
# vaak ADJ advmod
# lang ADJ advmod
# voor ADP case
# u PRON obl
# weer ADV advmod
# beter ADJ advmod
# bent AUX cop
# . PUNCT punct
# ['Corona', 'ziekenhuis', '  ', 'ziekenhuis', 'medicijnen', 'krijgen', 'ontsteking', 'bloedklonte', 'trombose', 'longembolie', 'klacht', '   ', 'extra', 'zuurstof', 'krijgen', 'slange', 'neus', 'eventueel', 'speciaal', 'apparaat', 'kapje', 'gezicht', '   ', 'medicijn', 'extra', 'zuurstof', 'genoeg', 'helpen', 'beademen', 'IC', '   ', 'opname', 'ziekenhuis', 'duren']
# [('Corona', 'ziekenhuis'), ('ziekenhuis', '  '), ('  ', 'ziekenhuis'), ('ziekenhuis', 'medicijnen'), ('medicijnen', 'krijgen'), ('krijgen', 'ontsteking'), ('ontsteking', 'bloedklonte'), ('bloedklonte', 'trombose'), ('trombose', 'longembolie'), ('longembolie', 'klacht'), ('klacht', '   '), ('   ', 'extra'), ('extra', 'zuurstof'), ('zuurstof', 'krijgen'), ('krijgen', 'slange'), ('slange', 'neus'), ('neus', 'eventueel'), ('eventueel', 'speciaal'), ('speciaal', 'apparaat'), ('apparaat', 'kapje'), ('kapje', 'gezicht'), ('gezicht', '   '), ('   ', 'medicijn'), ('medicijn', 'extra'), ('extra', 'zuurstof'), ('zuurstof', 'genoeg'), ('genoeg', 'helpen'), ('helpen', 'beademen'), ('beademen', 'IC'), ('IC', '   '), ('   ', 'opname'), ('opname', 'ziekenhuis'), ('ziekenhuis', 'duren')]
# Na ADP case
# corona PROPN ROOT
# . PUNCT punct
#    SPACE dep
# Meestal ADV advmod
# bent AUX ROOT
# u PRON nsubj
# snel ADJ advmod
# weer ADV advmod
# beter ADJ advmod
# na ADP case
# corona PROPN obl
# . PUNCT punct
#     SPACE dep
# Gezond ADJ amod
# leven NOUN obl
# helpt VERB ROOT
# uw PRON nmod:poss
# lichaam NOUN nsubj
# om ADP mark
# beter ADJ xcomp
# worden VERB advcl
# . PUNCT punct
# U PRON nsubj
# voelt VERB ROOT
# zich PRON expl:pv
# er ADV advmod
# ook ADV advmod
# beter ADJ advmod
# door ADP compound:prt
# . PUNCT punct
#     SPACE dep
# Eet VERB nsubj
# en CCONJ cc
# drink NOUN conj
# gezond ADJ ROOT
# . PUNCT punct
#     SPACE dep
# Beweeg NOUN case
# elke DET det
# dag NOUN ROOT
# , PUNCT punct
# maar CCONJ cc
# bouw VERB conj
# het DET obj
# rustig ADJ advmod
# op ADP compound:prt
# . PUNCT punct
#     SPACE dep
# Neem ADJ ROOT
# tijd NOUN fixed
# om ADP mark
# te ADP mark
# ontspannen VERB acl
# . PUNCT punct
#     SPACE dep
# Luister NOUN ROOT
# naar ADP case
# uw PRON nmod:poss
# lichaam NOUN nmod
# als SCONJ mark
# u PRON nsubj
# weer ADV advmod
# gaat VERB advcl
# werken VERB xcomp
# na ADP case
# corona PROPN obl
# . PUNCT punct
#     SPACE dep
# Soms ADV advmod
# houden VERB ROOT
# mensen NOUN nsubj
# langer ADJ advmod
# klachten NOUN obj
# na ADP case
# corona PROPN obl
# . PUNCT punct
#     SPACE dep
# Uw PRON nmod:poss
# huisarts NOUN obj
# kan AUX aux
# u PRON nsubj
# dan ADV advmod
# doorsturen VERB ROOT
# voor ADP case
# hulp NOUN obl
# en CCONJ cc
# steun NOUN conj
# . PUNCT punct
# ['corona', '  ', 'meestal', 'snel', 'corona', '   ', 'gezond', 'leven', 'helpen', 'lichaam', 'voelen', '   ', 'Eet', 'drink', 'gezond', '   ', 'beweeg', 'dag', 'bouw', 'rustig', '   ', 'nemen', 'tijd', 'ontspannen', '   ', 'luister', 'lichaam', 'gaan', 'werken', 'corona', '   ', 'soms', 'houden', 'mens', 'lang', 'klacht', 'corona', '   ', 'huisarts', 'doorsturen', 'hulp', 'steun']
# [('corona', '  '), ('  ', 'meestal'), ('meestal', 'snel'), ('snel', 'corona'), ('corona', '   '), ('   ', 'gezond'), ('gezond', 'leven'), ('leven', 'helpen'), ('helpen', 'lichaam'), ('lichaam', 'voelen'), ('voelen', '   '), ('   ', 'Eet'), ('Eet', 'drink'), ('drink', 'gezond'), ('gezond', '   '), ('   ', 'beweeg'), ('beweeg', 'dag'), ('dag', 'bouw'), ('bouw', 'rustig'), ('rustig', '   '), ('   ', 'nemen'), ('nemen', 'tijd'), ('tijd', 'ontspannen'), ('ontspannen', '   '), ('   ', 'luister'), ('luister', 'lichaam'), ('lichaam', 'gaan'), ('gaan', 'werken'), ('werken', 'corona'), ('corona', '   '), ('   ', 'soms'), ('soms', 'houden'), ('houden', 'mens'), ('mens', 'lang'), ('lang', 'klacht'), ('klacht', 'corona'), ('corona', '   '), ('   ', 'huisarts'), ('huisarts', 'doorsturen'), ('doorsturen', 'hulp'), ('hulp', 'steun')]
# Corona ADV advmod
# hebben VERB ROOT
# . PUNCT punct
#    SPACE dep
# Blijf VERB ROOT
# thuis ADV advmod
# als SCONJ mark
# je PRON nsubj
# je PRON nsubj
# ziek ADJ xcomp
# voelt VERB parataxis
# . PUNCT punct
#     SPACE dep
# Eet VERB ROOT
# en CCONJ cc
# drink ADJ conj
# genoeg ADV advmod
# . PUNCT punct
#     SPACE dep
# Je PRON nsubj
# kunt AUX aux
# paracetamol NOUN obj
# nemen VERB ROOT
# tegen ADP case
# pijn NOUN obl
# en CCONJ cc
# koorts NOUN conj
# . PUNCT punct
#     SPACE dep
# Bel PROPN ROOT
#   SPACE dep
# direct ADJ amod
#   SPACE dep
# de DET det
# huisarts NOUN obl
# of CCONJ cc
# huisartsen-spoedpost NOUN conj
# als SCONJ mark
# je PRON nsubj
# snel ADJ advmod
# of CCONJ cc
# moeilijk ADJ xcomp
# ademt VERB advcl
# . PUNCT punct
# Of SCONJ mark
# als SCONJ mark
# je PRON nsubj
# snel ADJ advmod
# zieker ADJ xcomp
# wordt VERB ROOT
# . PUNCT punct
#     SPACE dep
# Bel PROPN ROOT
# ook ADV advmod
#   SPACE dep
# direct ADJ advmod
#   SPACE dep
# als SCONJ mark
# je PRON nsubj
# in ADP parataxis
# de DET fixed
# war NOUN fixed
# bent AUX cop
# . PUNCT punct
# ['Corona', '  ', 'Blijf', 'thuis', 'ziek', 'voelen', '   ', 'Eet', 'Drink', 'genoeg', '   ', 'paracetamol', 'nemen', 'pijn', 'koorts', '   ', 'Bel', ' ', 'direct', ' ', 'huisarts', 'huisartsen-spoedpost', 'snel', 'moeilijk', 'admen', 'snel', 'ziek', '   ', 'Bel', ' ', 'direct', ' ', 'war']
# [('Corona', '  '), ('  ', 'Blijf'), ('Blijf', 'thuis'), ('thuis', 'ziek'), ('ziek', 'voelen'), ('voelen', '   '), ('   ', 'Eet'), ('Eet', 'Drink'), ('Drink', 'genoeg'), ('genoeg', '   '), ('   ', 'paracetamol'), ('paracetamol', 'nemen'), ('nemen', 'pijn'), ('pijn', 'koorts'), ('koorts', '   '), ('   ', 'Bel'), ('Bel', ' '), (' ', 'direct'), ('direct', ' '), (' ', 'huisarts'), ('huisarts', 'huisartsen-spoedpost'), ('huisartsen-spoedpost', 'snel'), ('snel', 'moeilijk'), ('moeilijk', 'admen'), ('admen', 'snel'), ('snel', 'ziek'), ('ziek', '   '), ('   ', 'Bel'), ('Bel', ' '), (' ', 'direct'), ('direct', ' '), (' ', 'war')]
# Coronaprik PROPN ROOT
# . PUNCT punct
#    SPACE dep
# De DET det
# coronaprik NOUN nsubj
# maakt VERB ROOT
# je PRON nsubj
# afweer ADV obj
# tegen ADP case
# het DET det
# coronavirus NOUN obl
# beter ADJ xcomp
# . PUNCT punct
#     SPACE dep
# Daardoor ADV advmod
# is AUX ROOT
# er ADV advmod
# minder DET det
# kans NOUN nsubj
# dat SCONJ mark
# je PRON nsubj
# ziek ADJ xcomp
# wordt AUX acl
# door ADP case
# het DET det
# virus NOUN obl
# . PUNCT punct
#     SPACE dep
# De DET det
# afweer NOUN nsubj
# die PRON obj
# het DET det
# lichaam NOUN obj
# heeft AUX aux
# gemaakt VERB acl:relcl
# na ADP case
# een DET det
# prik NOUN obl
# , PUNCT punct
# kan AUX aux
# na ADP case
# een DET det
# tijd NOUN obl
# vanzelf ADV advmod
# minder PRON advmod
# worden VERB ROOT
# . PUNCT punct
#     SPACE dep
# Een DET det
# prik NOUN nsubj
# in ADP case
# het DET det
# najaar NOUN nmod
# zorgt VERB ROOT
# ervoor ADV case
# dat SCONJ mark
# de DET det
# afweer NOUN nsubj
# weer ADV advmod
# beter ADJ xcomp
# wordt VERB advcl
# . PUNCT punct
#      SPACE dep
# Bijwerkingen PROPN ROOT
# die PRON nsubj
# het DET obl
# meest PRON fixed
# voorkomen VERB acl:relcl
# zijn AUX cop
# : PUNCT punct
# pijn NOUN ROOT
# op ADP case
# de DET det
# prikplek ADJ nmod
# , PUNCT punct
# koorts NOUN conj
# en CCONJ cc
# een DET det
# grieperig ADJ amod
# gevoel NOUN conj
# . PUNCT punct
#     SPACE dep
# Ernstige ADJ amod
# bijwerkingen NOUN nsubj
# komen VERB ROOT
# bijna ADV advmod
# nooit ADV advmod
# voor ADP compound:prt
# . PUNCT punct
# ['Coronaprik', '  ', 'coronaprik', 'maken', 'afweer', 'coronavirus', '   ', 'daardoor', 'kans', 'ziek', 'virus', '   ', 'afweer', 'lichaam', 'maken', 'prik', 'tijd', 'vanzelf', '   ', 'prik', 'najaar', 'zorgen', 'ervoor', 'afweer', '    ', 'bijwerking', 'veel', 'voorkomen', 'pijn', 'prikplek', 'koorts', 'grieperig', 'gevoel', '   ', 'Ernstig', 'bijwerking', 'komen']
# [('Coronaprik', '  '), ('  ', 'coronaprik'), ('coronaprik', 'maken'), ('maken', 'afweer'), ('afweer', 'coronavirus'), ('coronavirus', '   '), ('   ', 'daardoor'), ('daardoor', 'kans'), ('kans', 'ziek'), ('ziek', 'virus'), ('virus', '   '), ('   ', 'afweer'), ('afweer', 'lichaam'), ('lichaam', 'maken'), ('maken', 'prik'), ('prik', 'tijd'), ('tijd', 'vanzelf'), ('vanzelf', '   '), ('   ', 'prik'), ('prik', 'najaar'), ('najaar', 'zorgen'), ('zorgen', 'ervoor'), ('ervoor', 'afweer'), ('afweer', '    '), ('    ', 'bijwerking'), ('bijwerking', 'veel'), ('veel', 'voorkomen'), ('voorkomen', 'pijn'), ('pijn', 'prikplek'), ('prikplek', 'koorts'), ('koorts', 'grieperig'), ('grieperig', 'gevoel'), ('gevoel', '   '), ('   ', 'Ernstig'), ('Ernstig', 'bijwerking'), ('bijwerking', 'komen')]
# Corona PROPN ROOT
# . PUNCT punct
#    SPACE dep
# Blijf VERB ROOT
# thuis ADV advmod
# als SCONJ mark
# je PRON nsubj
# je PRON nsubj
# ziek ADJ xcomp
# voelt VERB parataxis
# . PUNCT punct
#     SPACE dep
# Eet VERB ROOT
# en CCONJ cc
# drink ADJ conj
# genoeg ADV advmod
# . PUNCT punct
#     SPACE dep
# Je PRON nsubj
# kunt AUX aux
# paracetamol NOUN obj
# nemen VERB ROOT
# tegen ADP case
# pijn NOUN obl
# en CCONJ cc
# koorts NOUN conj
# . PUNCT punct
#     SPACE dep
# Bel PROPN ROOT
#   SPACE dep
# direct ADJ amod
#   SPACE dep
# de DET det
# huisarts NOUN obl
# of CCONJ cc
# huisartsen-spoedpost NOUN conj
# als SCONJ mark
# je PRON nsubj
# snel ADJ advmod
# of CCONJ cc
# moeilijk ADJ xcomp
# ademt VERB advcl
# . PUNCT punct
# Of SCONJ mark
# als SCONJ mark
# je PRON nsubj
# snel ADJ advmod
# zieker ADJ xcomp
# wordt VERB ROOT
# . PUNCT punct
#     SPACE dep
# Bel PROPN ROOT
# ook ADV advmod
#   SPACE dep
# direct ADJ advmod
#   SPACE dep
# als SCONJ mark
# je PRON nsubj
# in ADP parataxis
# de DET fixed
# war NOUN fixed
# bent AUX cop
# . PUNCT punct
# ['Corona', '  ', 'Blijf', 'thuis', 'ziek', 'voelen', '   ', 'Eet', 'Drink', 'genoeg', '   ', 'paracetamol', 'nemen', 'pijn', 'koorts', '   ', 'Bel', ' ', 'direct', ' ', 'huisarts', 'huisartsen-spoedpost', 'snel', 'moeilijk', 'admen', 'snel', 'ziek', '   ', 'Bel', ' ', 'direct', ' ', 'war']
# [('Corona', '  '), ('  ', 'Blijf'), ('Blijf', 'thuis'), ('thuis', 'ziek'), ('ziek', 'voelen'), ('voelen', '   '), ('   ', 'Eet'), ('Eet', 'Drink'), ('Drink', 'genoeg'), ('genoeg', '   '), ('   ', 'paracetamol'), ('paracetamol', 'nemen'), ('nemen', 'pijn'), ('pijn', 'koorts'), ('koorts', '   '), ('   ', 'Bel'), ('Bel', ' '), (' ', 'direct'), ('direct', ' '), (' ', 'huisarts'), ('huisarts', 'huisartsen-spoedpost'), ('huisartsen-spoedpost', 'snel'), ('snel', 'moeilijk'), ('moeilijk', 'admen'), ('admen', 'snel'), ('snel', 'ziek'), ('ziek', '   '), ('   ', 'Bel'), ('Bel', ' '), (' ', 'direct'), ('direct', ' '), (' ', 'war')]
# Lang ADJ advmod
# klachten VERB ROOT
# na ADP case
# corona PROPN obl
# . PUNCT punct
#    SPACE dep
# Na ADP case
# corona ADV obl
# kunt AUX aux
# u PRON nsubj
# lang ADJ advmod
# moe ADJ ROOT
# of CCONJ cc
# benauwd ADJ conj
# zijn AUX cop
# . PUNCT punct
# U PRON nsubj
# voelt VERB ROOT
# zich PRON expl:pv
# niet ADV advmod
# fit ADJ xcomp
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# minder ADV advmod
# goed ADJ advmod
# denken VERB ROOT
# of CCONJ cc
# onthouden VERB conj
# . PUNCT punct
# Of CCONJ mark
# minder DET det
# ruiken VERB ROOT
# en CCONJ cc
# proeven NOUN conj
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# 1 NUM nummod
# klacht NOUN obj
# hebben VERB ROOT
# of CCONJ cc
# meer PRON det
# klachten NOUN obj
# tegelijk ADV advmod
# . PUNCT punct
#     SPACE dep
# Bij ADP case
# de DET det
# meeste ADV amod
# mensen NOUN obl
# gaan VERB ROOT
# de DET det
# problemen NOUN nsubj
# weer ADV advmod
# over ADP compound:prt
# . PUNCT punct
#     SPACE dep
# Zorg NOUN ROOT
# voor ADP case
# goede ADJ amod
# voeding NOUN nmod
# , PUNCT punct
# goede ADJ amod
# slaap NOUN conj
# en CCONJ cc
# genoeg ADV amod
# ontspanning NOUN conj
# . PUNCT punct
#     SPACE dep
# Wissel NOUN nsubj
# af ADP compound:prt
# tussen ADP case
# dingen NOUN obl
# doen VERB ROOT
# en CCONJ cc
# rust NOUN obj
# nemen VERB conj
# . PUNCT punct
#     SPACE dep
# Beweeg ADP case
# elke DET det
# dag NOUN ROOT
# . PUNCT punct
# Begin NOUN ROOT
# langzaam ADJ advmod
# en CCONJ cc
# rustig ADJ conj
# . PUNCT punct
# Beweeg NOUN nmod
# steeds ADV advmod
# iets PRON ROOT
# meer ADV amod
# . PUNCT punct
#     SPACE dep
# Blijft VERB ROOT
# u PRON nsubj
# erg ADJ advmod
# lang ADJ advmod
# klachten NOUN obj
# houden VERB xcomp
# ? PUNCT punct
# Bespreek PROPN ROOT
# dan ADV mark
# met ADP case
# uw PRON nmod:poss
# huisarts NOUN obl
# welke DET det
# hulp NOUN obj
# u PRON nsubj
# kunt AUX aux
# krijgen VERB advcl
# . PUNCT punct
# ['klacht', 'corona', '  ', 'corona', 'moe', 'benauwd', 'voelen', 'fit', '   ', 'goed', 'denken', 'onthouden', 'ruiken', 'proef', '   ', '1', 'klacht', 'klacht', 'tegelijk', '   ', 'veel', 'mens', 'gaan', 'probleem', '   ', 'zorg', 'goed', 'voeding', 'goed', 'slaap', 'genoeg', 'ontspanning', '   ', 'wissel', 'ding', 'rust', 'nemen', '   ', 'dag', 'begin', 'langzaam', 'rustig', 'beweeg', '   ', 'Blijven', 'erg', 'klacht', 'houden', 'Bespreek', 'huisarts', 'hulp', 'krijgen']
# [('klacht', 'corona'), ('corona', '  '), ('  ', 'corona'), ('corona', 'moe'), ('moe', 'benauwd'), ('benauwd', 'voelen'), ('voelen', 'fit'), ('fit', '   '), ('   ', 'goed'), ('goed', 'denken'), ('denken', 'onthouden'), ('onthouden', 'ruiken'), ('ruiken', 'proef'), ('proef', '   '), ('   ', '1'), ('1', 'klacht'), ('klacht', 'klacht'), ('klacht', 'tegelijk'), ('tegelijk', '   '), ('   ', 'veel'), ('veel', 'mens'), ('mens', 'gaan'), ('gaan', 'probleem'), ('probleem', '   '), ('   ', 'zorg'), ('zorg', 'goed'), ('goed', 'voeding'), ('voeding', 'goed'), ('goed', 'slaap'), ('slaap', 'genoeg'), ('genoeg', 'ontspanning'), ('ontspanning', '   '), ('   ', 'wissel'), ('wissel', 'ding'), ('ding', 'rust'), ('rust', 'nemen'), ('nemen', '   '), ('   ', 'dag'), ('dag', 'begin'), ('begin', 'langzaam'), ('langzaam', 'rustig'), ('rustig', 'beweeg'), ('beweeg', '   '), ('   ', 'Blijven'), ('Blijven', 'erg'), ('erg', 'klacht'), ('klacht', 'houden'), ('houden', 'Bespreek'), ('Bespreek', 'huisarts'), ('huisarts', 'hulp'), ('hulp', 'krijgen')]
# Corona ADV nsubj
# voorkomen VERB ROOT
# . PUNCT punct
#    SPACE dep
# U PRON nsubj
# kunt AUX aux
# corona ADV obj
# krijgen VERB ROOT
# als SCONJ mark
# u PRON nsubj
# druppeltjes NOUN obj
# met ADP case
# virus NOUN nmod
# inademt VERB advcl
# . PUNCT punct
#     SPACE dep
# Of SCONJ mark
# als SCONJ mark
# u PRON nsubj
# druppeltjes NOUN obj
# op ADP case
# uw PRON nmod:poss
# handen NOUN obl
# krijgt VERB ROOT
# en CCONJ cc
# dan ADV advmod
# uw PRON nmod:poss
# gezicht NOUN obj
# aanraakt VERB conj
# . PUNCT punct
#     SPACE dep
# Adviezen NOUN ROOT
# om ADP mark
# het DET det
# virus NOUN obj
# niet ADV advmod
# te ADP mark
# krijgen VERB acl
# : PUNCT punct
#     SPACE dep
# Was AUX cop
# uw PRON nmod:poss
# handen NOUN parataxis
# vaak ADJ advmod
# met ADP case
# water NOUN obl
# en CCONJ cc
# zeep NOUN conj
# . PUNCT punct
#      SPACE dep
# Raak VERB ROOT
# zo ADV amod
# weinig PRON advmod
# mogelijk ADJ advmod
# uw PRON nmod:poss
# ogen NOUN obj
# , PUNCT punct
# neus NOUN conj
# en CCONJ cc
# mond NOUN conj
# aan ADP compound:prt
# . PUNCT punct
#      SPACE dep
# Geef VERB ROOT
# anderen ADJ obj
# geen DET det
# hand. SYM obj
#         SPACE dep
# Prikken NOUN nsubj
# tegen ADP case
# corona PROPN nmod
# maken VERB ROOT
# uw PRON nmod:poss
# afweer NOUN obj
# tegen ADP case
# het DET det
# coronavirus NOUN obl
# beter ADJ xcomp
# . PUNCT punct
#     SPACE dep
# Door ADP case
# een DET det
# prik NOUN obl
# is VERB ROOT
# er ADV advmod
# minder DET det
# kans NOUN nsubj
# dat SCONJ mark
# u PRON nsubj
# ziek ADJ xcomp
# wordt AUX acl
# door ADP case
# het DET det
# virus NOUN obl
# . PUNCT punct
# ['Corona', 'voorkomen', '  ', 'corona', 'krijgen', 'druppelt', 'virus', 'inadmen', '   ', 'druppelt', 'hand', 'krijgen', 'gezicht', 'aanraakt', '   ', 'Adviezen', 'virus', 'krijgen', '   ', 'hand', 'water', 'zeep', '    ', 'Raak', 'oog', 'neus', 'mond', '    ', 'geven', 'hand.', '       ', 'Prikken', 'corona', 'maken', 'afweer', 'coronavirus', '   ', 'prik', 'kans', 'ziek', 'virus']
# [('Corona', 'voorkomen'), ('voorkomen', '  '), ('  ', 'corona'), ('corona', 'krijgen'), ('krijgen', 'druppelt'), ('druppelt', 'virus'), ('virus', 'inadmen'), ('inadmen', '   '), ('   ', 'druppelt'), ('druppelt', 'hand'), ('hand', 'krijgen'), ('krijgen', 'gezicht'), ('gezicht', 'aanraakt'), ('aanraakt', '   '), ('   ', 'Adviezen'), ('Adviezen', 'virus'), ('virus', 'krijgen'), ('krijgen', '   '), ('   ', 'hand'), ('hand', 'water'), ('water', 'zeep'), ('zeep', '    '), ('    ', 'Raak'), ('Raak', 'oog'), ('oog', 'neus'), ('neus', 'mond'), ('mond', '    '), ('    ', 'geven'), ('geven', 'hand.'), ('hand.', '       '), ('       ', 'Prikken'), ('Prikken', 'corona'), ('corona', 'maken'), ('maken', 'afweer'), ('afweer', 'coronavirus'), ('coronavirus', '   '), ('   ', 'prik'), ('prik', 'kans'), ('kans', 'ziek'), ('ziek', 'virus')]
# Naaste ADJ ROOT
# met ADP case
# corona PROPN nmod
# . PUNCT punct
#    SPACE dep
# Uw PRON nmod:poss
# naaste ADJ nsubj:pass
# is AUX aux:pass
# verzwakt VERB ROOT
# na ADP case
# opname NOUN obl
# in ADP case
# het DET det
# ziekenhuis NOUN nmod
# met ADP case
# corona PROPN nmod
# . PUNCT punct
#     SPACE dep
# Het PRON nsubj
# kan AUX aux
# lang ADJ advmod
# duren VERB ROOT
# om ADP mark
# te ADP mark
# herstellen VERB advcl
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# bent AUX aux
# misschien ADV advmod
# mantelzorger ADJ xcomp
# geworden VERB ROOT
# . PUNCT punct
#     SPACE dep
# Ook ADV amod
# voor ADP case
# u PRON nsubj
# is AUX cop
# het PRON nsubj
# een DET det
# heftige ADJ amod
# periode NOUN ROOT
# . PUNCT punct
#     SPACE dep
# Praat VERB ROOT
# erover ADV advmod
# met ADP case
# uw PRON nmod:poss
# huisarts NOUN obl
# . PUNCT punct
# ['naaste', 'corona', '  ', 'naast', 'verzwakken', 'opname', 'ziekenhuis', 'corona', '   ', 'duren', 'herstellen', '   ', 'mantelzorg', '   ', 'heftig', 'periode', '   ', 'Praat', 'erover', 'huisarts']
# [('naaste', 'corona'), ('corona', '  '), ('  ', 'naast'), ('naast', 'verzwakken'), ('verzwakken', 'opname'), ('opname', 'ziekenhuis'), ('ziekenhuis', 'corona'), ('corona', '   '), ('   ', 'duren'), ('duren', 'herstellen'), ('herstellen', '   '), ('   ', 'mantelzorg'), ('mantelzorg', '   '), ('   ', 'heftig'), ('heftig', 'periode'), ('periode', '   '), ('   ', 'Praat'), ('Praat', 'erover'), ('erover', 'huisarts')]
# Levenseinde PROPN ROOT
# . PUNCT punct
#    SPACE dep
# Het PRON expl
# is AUX cop
# belangrijk ADJ ROOT
# om ADP mark
# met ADP case
# uw PRON nmod:poss
# arts NOUN obl
# te ADP mark
# praten VERB csubj
# over ADP case
# het DET det
# laatste ADJ amod
# stuk NOUN nmod
# van ADP case
# uw PRON nmod:poss
# leven NOUN nmod
# . PUNCT punct
#      SPACE dep
# Wat PRON nsubj:pass
# zijn AUX cop
# uw PRON nmod:poss
# vragen NOUN nsubj
# , PUNCT punct
# wensen NOUN conj
# en CCONJ cc
# verwachtingen NOUN conj
# ? PUNCT punct
#      SPACE dep
# Kunt AUX aux
# en CCONJ cc
# wilt VERB conj
# u PRON nsubj:pass
# gereanimeerd VERB ROOT
# worden AUX aux:pass
# bij ADP case
# een DET det
# hartstilstand NOUN obl
# ? PUNCT punct
#     SPACE dep
# Wat PRON nsubj
# is AUX aux:pass
# lijden VERB ROOT
# voor ADP case
# u PRON obl
# ? PUNCT punct
# Welke DET det
# behandelingen NOUN nsubj
# zijn VERB ROOT
# er ADV advmod
# om ADP case
# pijn NOUN obl
# en CCONJ cc
# lijden NOUN conj
# te ADP mark
# verlichten VERB conj
# ? PUNCT punct
#    SPACE dep
# Wilt VERB ROOT
# u PRON nsubj
# een DET det
# behandeling NOUN obj
# wel ADV advmod
# of CCONJ cc
# juist ADJ advmod
# niet ADV advmod
# ? PUNCT punct
# Maak VERB ROOT
# dan SCONJ mark
# een DET det
# wilsverklaring NOUN obj
# . PUNCT punct
#    SPACE dep
# Denkt VERB ROOT
# u PRON nsubj
# aan ADP case
# euthanasie NOUN obl
# ? PUNCT punct
#     SPACE dep
# Hoe ADV advmod
# kunt AUX aux
# u PRON nsubj
# uw PRON nmod:poss
# leven NOUN obl
# zo ADV advmod
# goed ADJ advmod
# mogelijk ADJ advcl
# afronden VERB ROOT
# ? PUNCT punct
# ['Levenseinde', '  ', 'belangrijk', 'arts', 'praten', 'laat', 'stuk', 'leven', '    ', 'vraag', 'wens', 'verwachting', '    ', 'willen', 'reanimeren', 'hartstilstand', '   ', 'lijden', 'behandeling', 'pijn', 'lijden', 'verlichten', '  ', 'Wilt', 'behandeling', 'Maak', 'wilsverklaring', '  ', 'denkt', 'euthanasie', '   ', 'leven', 'goed', 'afronden']
# [('Levenseinde', '  '), ('  ', 'belangrijk'), ('belangrijk', 'arts'), ('arts', 'praten'), ('praten', 'laat'), ('laat', 'stuk'), ('stuk', 'leven'), ('leven', '    '), ('    ', 'vraag'), ('vraag', 'wens'), ('wens', 'verwachting'), ('verwachting', '    '), ('    ', 'willen'), ('willen', 'reanimeren'), ('reanimeren', 'hartstilstand'), ('hartstilstand', '   '), ('   ', 'lijden'), ('lijden', 'behandeling'), ('behandeling', 'pijn'), ('pijn', 'lijden'), ('lijden', 'verlichten'), ('verlichten', '  '), ('  ', 'Wilt'), ('Wilt', 'behandeling'), ('behandeling', 'Maak'), ('Maak', 'wilsverklaring'), ('wilsverklaring', '  '), ('  ', 'denkt'), ('denkt', 'euthanasie'), ('euthanasie', '   '), ('   ', 'leven'), ('leven', 'goed'), ('goed', 'afronden')]
# Darmkanker PROPN ROOT
# . PUNCT punct
#    SPACE dep
# Klachten NOUN nsubj
# bij ADP case
# darmkanker NOUN nmod
# zijn AUX cop
# bijvoorbeeld ADV advmod
# : PUNCT punct
#   SPACE dep
# poep NOUN ROOT
# die PRON nsubj
# anders ADV acl:relcl
# is AUX cop
# dan ADV mark
# normaal ADJ advcl
# : PUNCT punct
# dunner NOUN obl
# of CCONJ cc
# dikker NOUN conj
#   SPACE dep
# vaker ADJ conj
# of CCONJ cc
# minder PRON advmod
# vaak ADJ conj
# naar ADP case
# de DET det
# wc NOUN nmod
#   SPACE dep
# bloed NOUN conj
# of CCONJ cc
# slijm NOUN conj
# bij ADP case
# uw PRON nmod:poss
# poep NOUN nmod
#     SPACE dep
# Met ADP case
# een DET det
# darmonderzoek NOUN obl
# is AUX aux
# te ADP mark
# zien VERB ROOT
# of SCONJ mark
# u PRON nsubj
# darmkanker NOUN obj
# heeft VERB ccomp
# . PUNCT punct
#   SPACE dep
# Zit VERB ROOT
# de DET det
# kanker NOUN nsubj
# alleen ADV amod
# in ADP case
# uw PRON nmod:poss
# darm NOUN obl
# ? PUNCT punct
# Een DET det
# arts NOUN nsubj
# kan AUX aux
# dan ADV advmod
# het DET det
# zieke ADJ amod
# deel NOUN obj
# van ADP case
# de DET det
# darm NOUN nmod
# weghalen VERB ROOT
# . PUNCT punct
# U PRON nsubj
# kunt AUX aux
# dan ADV advmod
# genezen VERB ROOT
# . PUNCT punct
#   SPACE dep
# Groeit VERB ROOT
# de DET det
# kanker NOUN nsubj
# ook ADV advmod
# op ADP case
# andere ADJ amod
# plekken NOUN obl
# ? PUNCT punct
# U PRON nsubj
# kunt AUX aux
# behandelingen NOUN obj
# krijgen VERB ROOT
# om ADP mark
# de DET det
# ziekte NOUN obj
# te ADP mark
# remmen VERB advcl
# . PUNCT punct
# ['darmkanker', '  ', 'klacht', 'darmkanker', ' ', 'poep', 'normaal', 'dunner', 'dikker', ' ', 'vaak', 'wc', ' ', 'bloed', 'slijm', 'poep', '   ', 'darmonderzoek', 'zien', 'darmkanker', ' ', 'Zit', 'kanker', 'darm', 'arts', 'ziek', 'deel', 'darm', 'weghalen', 'genezen', ' ', 'Groeit', 'kanker', 'plek', 'behandeling', 'krijgen', 'ziekte', 'remmen']
# [('darmkanker', '  '), ('  ', 'klacht'), ('klacht', 'darmkanker'), ('darmkanker', ' '), (' ', 'poep'), ('poep', 'normaal'), ('normaal', 'dunner'), ('dunner', 'dikker'), ('dikker', ' '), (' ', 'vaak'), ('vaak', 'wc'), ('wc', ' '), (' ', 'bloed'), ('bloed', 'slijm'), ('slijm', 'poep'), ('poep', '   '), ('   ', 'darmonderzoek'), ('darmonderzoek', 'zien'), ('zien', 'darmkanker'), ('darmkanker', ' '), (' ', 'Zit'), ('Zit', 'kanker'), ('kanker', 'darm'), ('darm', 'arts'), ('arts', 'ziek'), ('ziek', 'deel'), ('deel', 'darm'), ('darm', 'weghalen'), ('weghalen', 'genezen'), ('genezen', ' '), (' ', 'Groeit'), ('Groeit', 'kanker'), ('kanker', 'plek'), ('plek', 'behandeling'), ('behandeling', 'krijgen'), ('krijgen', 'ziekte'), ('ziekte', 'remmen')]
# Lange ADJ amod
# tijd NOUN obl
# of CCONJ cc
# vaak ADJ advmod
# neusklachten VERB ROOT
# . PUNCT punct
#    SPACE dep
# U PRON nsubj
# heeft AUX ROOT
# lang ADJ obl
# of CCONJ cc
# vaak ADJ conj
# last NOUN obj
# van ADP case
# een DET det
# verstopte VERB amod
# neus NOUN nmod
# , PUNCT punct
# een DET det
# loopneus NOUN conj
# , PUNCT punct
# niezen VERB conj
# of CCONJ cc
# jeuk NOUN conj
# in ADP case
# de DET det
# neus NOUN nmod
# . PUNCT punct
#     SPACE dep
# Meestal ADV advmod
# komt VERB ROOT
# dit PRON nsubj
# doordat SCONJ mark
# u PRON nsubj
# gevoelig ADJ advcl
# bent AUX cop
# voor ADP case
# bepaalde VERB amod
# dingen NOUN obl
# , PUNCT punct
# zoals SCONJ mark
# rook NOUN nmod
# of CCONJ cc
# schilfers NOUN conj
# van ADP case
# dieren NOUN nmod
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# dan ADV advmod
# proberen VERB ROOT
# om ADP mark
# contact NOUN obj
# hiermee ADV advmod
# te ADP mark
# voorkomen VERB advcl
# . PUNCT punct
# Bijvoorbeeld ADV amod
# geen DET det
# dieren NOUN obl
# aaien ADV ROOT
# als SCONJ mark
# u PRON nsubj
# daar ADV obl
# last NOUN obj
# van ADP case
# krijgt VERB advcl
# . PUNCT punct
#     SPACE dep
# Rookt VERB ROOT
# u PRON nsubj
# ? PUNCT punct
# Stop VERB ROOT
# dan ADV advmod
# met ADP case
# roken VERB obl
# . PUNCT punct
#     SPACE dep
# Wat PRON obj
# kan AUX aux
# helpen VERB advcl
# is AUX aux
# een DET det
# neus-spray NOUN nsubj
# tegen ADP case
# allergie NOUN nmod
# of CCONJ cc
# tegen ADP compound:prt
# ontstekingen VERB ROOT
# . PUNCT punct
# ['Lang', 'tijd', 'neusklachten', '  ', 'last', 'verstopt', 'neus', 'loopneus', 'niezen', 'jeuk', 'neus', '   ', 'meestal', 'komen', 'doordat', 'gevoelig', 'bepalen', 'ding', 'rook', 'schilfer', 'dier', '   ', 'proberen', 'contact', 'hiermee', 'voorkomen', 'dier', 'Aaien', 'last', 'krijgen', '   ', 'Roken', 'stop', 'roken', '   ', 'helpen', 'neus-spray', 'allergie', 'ontsteking']
# [('Lang', 'tijd'), ('tijd', 'neusklachten'), ('neusklachten', '  '), ('  ', 'last'), ('last', 'verstopt'), ('verstopt', 'neus'), ('neus', 'loopneus'), ('loopneus', 'niezen'), ('niezen', 'jeuk'), ('jeuk', 'neus'), ('neus', '   '), ('   ', 'meestal'), ('meestal', 'komen'), ('komen', 'doordat'), ('doordat', 'gevoelig'), ('gevoelig', 'bepalen'), ('bepalen', 'ding'), ('ding', 'rook'), ('rook', 'schilfer'), ('schilfer', 'dier'), ('dier', '   '), ('   ', 'proberen'), ('proberen', 'contact'), ('contact', 'hiermee'), ('hiermee', 'voorkomen'), ('voorkomen', 'dier'), ('dier', 'Aaien'), ('Aaien', 'last'), ('last', 'krijgen'), ('krijgen', '   '), ('   ', 'Roken'), ('Roken', 'stop'), ('stop', 'roken'), ('roken', '   '), ('   ', 'helpen'), ('helpen', 'neus-spray'), ('neus-spray', 'allergie'), ('allergie', 'ontsteking')]
# Eczeem PROPN ROOT
# met ADP case
# schilfers NOUN nmod
# op ADP case
# hoofd NOUN nmod
# , PUNCT punct
# gezicht NOUN conj
# of CCONJ cc
# oren NOUN conj
# . PUNCT punct
#    SPACE dep
# Op ADP case
# uw PRON nmod:poss
# hoofd NOUN obl
# en CCONJ cc
# gezicht NOUN conj
# kunt AUX aux
# u PRON nsubj
# eczeem NOUN obj
# hebben VERB ROOT
# met ADP case
# vette ADV amod
# schilfers NOUN obl
# . PUNCT punct
#     SPACE dep
# De DET det
# schilfers NOUN nsubj
# zitten VERB ROOT
# vaak ADJ advmod
# tussen ADP case
# de DET det
# haren NOUN obl
# , PUNCT punct
# wimpers NOUN conj
# , PUNCT punct
# in ADP case
# de DET det
# wenkbrauwen NOUN obl
# , PUNCT punct
# naast ADP case
# de DET det
# neus NOUN obl
# en CCONJ cc
# achter ADP conj
# en CCONJ cc
# in ADP case
# de DET det
# oren NOUN conj
# . PUNCT punct
#     SPACE dep
# Het PRON nsubj
# komt VERB ROOT
# door ADP case
# veel DET det
# gistcellen NOUN obl
# op ADP case
# de DET det
# huid NOUN nmod
# . PUNCT punct
#     SPACE dep
# Draag NOUN ROOT
# geen DET det
# pet NOUN parataxis
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# een DET det
# crème NOUN obj
# , PUNCT punct
# shampoo ADJ conj
# of CCONJ cc
# lotion NOUN conj
# gebruiken VERB ROOT
# die PRON nsubj
# werkt VERB acl:relcl
# tegen ADP case
# gisten NOUN obl
# . PUNCT punct
#     SPACE dep
# Bij ADP case
# baby's NOUN obl
# heet VERB ROOT
# dit DET det
# eczeem NOUN nsubj
# berg NOUN xcomp
# . PUNCT punct
# Dit PRON nsubj
# gaat VERB ROOT
# vanzelf ADV advmod
# over ADP compound:prt
# . PUNCT punct
# ['Eczeem', 'schilfer', 'hoofd', 'gezicht', 'oor', '  ', 'hoofd', 'gezicht', 'eczeem', 'veten', 'schilfer', '   ', 'schilfer', 'zitten', 'haar', 'wimper', 'wenkbrauw', 'neus', 'oor', '   ', 'komen', 'gistcel', 'huid', '   ', 'draag', 'pet', '   ', 'crème', 'shampoo', 'lotion', 'gebruiken', 'werken', 'gist', '   ', 'baby', 'heten', 'eczeem', 'berg', 'gaan', 'vanzelf']
# [('Eczeem', 'schilfer'), ('schilfer', 'hoofd'), ('hoofd', 'gezicht'), ('gezicht', 'oor'), ('oor', '  '), ('  ', 'hoofd'), ('hoofd', 'gezicht'), ('gezicht', 'eczeem'), ('eczeem', 'veten'), ('veten', 'schilfer'), ('schilfer', '   '), ('   ', 'schilfer'), ('schilfer', 'zitten'), ('zitten', 'haar'), ('haar', 'wimper'), ('wimper', 'wenkbrauw'), ('wenkbrauw', 'neus'), ('neus', 'oor'), ('oor', '   '), ('   ', 'komen'), ('komen', 'gistcel'), ('gistcel', 'huid'), ('huid', '   '), ('   ', 'draag'), ('draag', 'pet'), ('pet', '   '), ('   ', 'crème'), ('crème', 'shampoo'), ('shampoo', 'lotion'), ('lotion', 'gebruiken'), ('gebruiken', 'werken'), ('werken', 'gist'), ('gist', '   '), ('   ', 'baby'), ('baby', 'heten'), ('heten', 'eczeem'), ('eczeem', 'berg'), ('berg', 'gaan'), ('gaan', 'vanzelf')]
# Zon PROPN ROOT
# en CCONJ cc
# zonnebrand NOUN conj
# . PUNCT punct
#    SPACE dep
# Uw PRON nmod:poss
# huid NOUN nsubj
# kan AUX aux
# verbranden VERB ROOT
# als SCONJ mark
# er ADV advmod
# te ADV amod
# veel DET det
# zonlicht NOUN nsubj
# op ADP case
# komt VERB advcl
# . PUNCT punct
#     SPACE dep
# Hoe ADV advmod
# snel ADJ advmod
# uw PRON nmod:poss
# huid NOUN obj
# verbrandt VERB advcl
# , PUNCT punct
# hangt VERB ROOT
# af ADP compound:prt
# van ADP case
# uw PRON nmod:poss
# huidtype NOUN obl
# . PUNCT punct
#     SPACE dep
# Bescherm PROPN ROOT
# uw PRON nmod:poss
# huid NOUN obj
# en CCONJ cc
# uw PRON nmod:poss
# ogen NOUN conj
# tegen ADP case
# zonverbranding NOUN obl
# . PUNCT punct
#     SPACE dep
# Ga VERB ROOT
# meteen ADV advmod
# uit ADP case
# de DET det
# zon NOUN obl
# als SCONJ mark
# u PRON nsubj
# merkt VERB advcl
# dat SCONJ mark
# uw PRON nmod:poss
# huid NOUN nsubj
# verbrandt VERB ccomp
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# de DET det
# huid NOUN obj
# koelen NOUN nmod
# met ADP case
# natte ADJ amod
# doeken NOUN ROOT
# . PUNCT punct
# Dat PRON nsubj
# helpt VERB ROOT
# tegen ADP case
# de DET det
# pijn NOUN obl
# . PUNCT punct
#     SPACE dep
# Blijf VERB ROOT
# in ADP case
# ieder DET det
# geval NOUN obl
# 3 NUM nummod
# dagen NOUN obl
# uit ADP case
# de DET det
# zon NOUN obl
# om ADP mark
# uw PRON nmod:poss
# huid NOUN obj
# beter ADJ advmod
# te ADP mark
# laten VERB csubj
# worden AUX aux:pass
# . PUNCT punct
# ['Zon', 'zonnebrand', '  ', 'huid', 'verbranden', 'zonlicht', 'komen', '   ', 'snel', 'huid', 'verbranden', 'hangen', 'huidtype', '   ', 'Bescherm', 'huid', 'oog', 'zonverbranding', '   ', 'Ga', 'meteen', 'zon', 'merken', 'huid', 'verbranden', '   ', 'huid', 'koel', 'nat', 'doek', 'meehelpen', 'pijn', '   ', 'Blijf', 'geval', '3', 'dag', 'zon', 'huid', 'laten']
# [('Zon', 'zonnebrand'), ('zonnebrand', '  '), ('  ', 'huid'), ('huid', 'verbranden'), ('verbranden', 'zonlicht'), ('zonlicht', 'komen'), ('komen', '   '), ('   ', 'snel'), ('snel', 'huid'), ('huid', 'verbranden'), ('verbranden', 'hangen'), ('hangen', 'huidtype'), ('huidtype', '   '), ('   ', 'Bescherm'), ('Bescherm', 'huid'), ('huid', 'oog'), ('oog', 'zonverbranding'), ('zonverbranding', '   '), ('   ', 'Ga'), ('Ga', 'meteen'), ('meteen', 'zon'), ('zon', 'merken'), ('merken', 'huid'), ('huid', 'verbranden'), ('verbranden', '   '), ('   ', 'huid'), ('huid', 'koel'), ('koel', 'nat'), ('nat', 'doek'), ('doek', 'meehelpen'), ('meehelpen', 'pijn'), ('pijn', '   '), ('   ', 'Blijf'), ('Blijf', 'geval'), ('geval', '3'), ('3', 'dag'), ('dag', 'zon'), ('zon', 'huid'), ('huid', 'laten')]
# Contacteczeem NOUN ROOT
# . PUNCT punct
#    SPACE dep
# Je PRON nsubj
# kunt AUX aux
# eczeem NOUN obj
# krijgen VERB ROOT
# door ADP case
# bijvoorbeeld ADV amod
# zeep NOUN obl
# , PUNCT punct
# schoonmaakmiddelen NOUN conj
# , PUNCT punct
# bloemenwater NOUN conj
# , PUNCT punct
# metaal NOUN conj
# ( PUNCT punct
# bijvoorbeeld ADV amod
# van ADP case
# sieraden NOUN nmod
# ) PUNCT punct
# , PUNCT punct
# rubber NOUN conj
# of CCONJ cc
# make-up NOUN conj
# . PUNCT punct
#   SPACE dep
# Dit PRON nsubj
# heet VERB ROOT
# contacteczeem NOUN obl
# . PUNCT punct
#   SPACE dep
# Als SCONJ mark
# duidelijk ADJ advcl
# is AUX cop
# wat PRON obj
# je PRON nsubj
# huid NOUN obj
# irriteert VERB csubj
# , PUNCT punct
# kun AUX aux
# je PRON nsubj
# proberen VERB ROOT
# om ADP mark
# dit PRON obj
# niet ADV advmod
# meer ADV advmod
# aan ADP compound:prt
# te ADP mark
# raken VERB xcomp
# . PUNCT punct
#   SPACE dep
# Gebruik NOUN ROOT
# elke DET det
# dag NOUN obl
# een DET det
# verzachtende VERB amod
# zalf NOUN nsubj
# of CCONJ cc
# crème NOUN conj
# . PUNCT punct
# Dit PRON nsubj
# voorkomt VERB ROOT
# dat SCONJ mark
# je PRON nsubj
# huid NOUN obj
# uitdroogt VERB ccomp
# . PUNCT punct
#   SPACE dep
# Als SCONJ mark
# je PRON nsubj
# klachten NOUN nsubj
# niet ADV advmod
# weggaan ADV advcl
# , PUNCT punct
# kan AUX aux
# de DET det
# huisarts NOUN iobj
# een DET det
# recept NOUN obj
# voor ADP case
# hormoonzalf ADJ nmod
# geven VERB ROOT
# . PUNCT punct
# ['Contacteczeem', '  ', 'eczeem', 'krijgen', 'zeep', 'schoonmaakmiddelen', 'bloemenwater', 'metaal', 'sieraad', 'rubber', 'make-up', ' ', 'heten', 'contacteczeem', ' ', 'duidelijk', 'huid', 'irriteren', 'kunnen', 'proberen', 'uitraken', ' ', 'gebruik', 'dag', 'verzachten', 'zalf', 'crème', 'voorkomen', 'huid', 'uitdrogen', ' ', 'klacht', 'weggaan', 'huisarts', 'recept', 'hormoonzalf']
# [('Contacteczeem', '  '), ('  ', 'eczeem'), ('eczeem', 'krijgen'), ('krijgen', 'zeep'), ('zeep', 'schoonmaakmiddelen'), ('schoonmaakmiddelen', 'bloemenwater'), ('bloemenwater', 'metaal'), ('metaal', 'sieraad'), ('sieraad', 'rubber'), ('rubber', 'make-up'), ('make-up', ' '), (' ', 'heten'), ('heten', 'contacteczeem'), ('contacteczeem', ' '), (' ', 'duidelijk'), ('duidelijk', 'huid'), ('huid', 'irriteren'), ('irriteren', 'kunnen'), ('kunnen', 'proberen'), ('proberen', 'uitraken'), ('uitraken', ' '), (' ', 'gebruik'), ('gebruik', 'dag'), ('dag', 'verzachten'), ('verzachten', 'zalf'), ('zalf', 'crème'), ('crème', 'voorkomen'), ('voorkomen', 'huid'), ('huid', 'uitdrogen'), ('uitdrogen', ' '), (' ', 'klacht'), ('klacht', 'weggaan'), ('weggaan', 'huisarts'), ('huisarts', 'recept'), ('recept', 'hormoonzalf')]
# Eczeem PROPN ROOT
# door ADP case
# erfelijke ADJ amod
# aanleg NOUN nmod
# . PUNCT punct
#    SPACE dep
# Eczeem PROPN nsubj
# door ADP case
# erfelijke ADJ amod
# aanleg NOUN nmod
# begint VERB ROOT
# al ADV advmod
# op ADP case
# jonge ADJ amod
# leeftijd NOUN obl
# . PUNCT punct
#     SPACE dep
# Het PRON nsubj
# geeft VERB ROOT
# een DET det
# jeukende VERB amod
# huid NOUN obj
# , PUNCT punct
# met ADP case
# schilfers NOUN nmod
# , PUNCT punct
# bultjes NOUN conj
# , PUNCT punct
# kloofjes NOUN conj
# of CCONJ cc
# korstjes NOUN conj
# . PUNCT punct
#     SPACE dep
# Wassen ADJ nsubj
# met ADP case
# water NOUN nmod
# en CCONJ cc
# zeep NOUN conj
# maakt VERB ROOT
# het DET det
# eczeem NOUN obj
# erger ADJ xcomp
# . PUNCT punct
#     SPACE dep
# 2 NUM nummod
# of CCONJ cc
# 3 NUM conj
# keer NOUN nmod
# per ADP case
# week NOUN nmod
# douchen/baden PROPN nsubj
# is AUX cop
# genoeg ADV ROOT
# . PUNCT punct
# Het DET ROOT
# liefst ADV fixed
# zonder ADP case
# zeep NOUN nmod
# . PUNCT punct
#     SPACE dep
# Smeer ADJ ROOT
# elke DET det
# dag NOUN obl
# een DET det
# verzachtende VERB amod
# zalf NOUN obj
# of CCONJ cc
# crème NOUN conj
# op ADP case
# het DET det
# eczeem NOUN nmod
# . PUNCT punct
# Bijvoorbeeld ADV advmod
# lanette VERB ROOT
# crème ADJ obj
# of CCONJ cc
# koelzalf ADJ conj
# . PUNCT punct
#      SPACE dep
# Soms ADV advmod
# is AUX cop
# een DET det
# hormoonzalf ADJ nsubj
# nodig ADJ ROOT
# . PUNCT punct
#     SPACE dep
# Bij ADP case
# dit DET det
# eczeem NOUN obl
# is AUX ROOT
# er ADV advmod
# meer DET det
# kans NOUN nsubj
# op ADP case
# hooikoorts NOUN nmod
# en CCONJ cc
# astma NOUN conj
# . PUNCT punct
# ['Eczeem', 'erfelijk', 'aanleg', '  ', 'Eczeem', 'erfelijk', 'aanleg', 'beginnen', 'jong', 'leeftijd', '   ', 'geven', 'jeuken', 'huid', 'schilfer', 'bult', 'kloof', 'korst', '   ', 'Wassen', 'water', 'zeep', 'maken', 'eczeem', 'erg', '   ', '2', '3', 'keer', 'week', 'douchen/baden', 'genoeg', 'liefst', 'zeep', '   ', 'Smeer', 'dag', 'verzachten', 'zalf', 'crème', 'eczeem', 'laneten', 'crème', 'koelzalf', '    ', 'soms', 'hormoonzalf', 'nodig', '   ', 'eczeem', 'kans', 'hooikoort', 'astma']
# [('Eczeem', 'erfelijk'), ('erfelijk', 'aanleg'), ('aanleg', '  '), ('  ', 'Eczeem'), ('Eczeem', 'erfelijk'), ('erfelijk', 'aanleg'), ('aanleg', 'beginnen'), ('beginnen', 'jong'), ('jong', 'leeftijd'), ('leeftijd', '   '), ('   ', 'geven'), ('geven', 'jeuken'), ('jeuken', 'huid'), ('huid', 'schilfer'), ('schilfer', 'bult'), ('bult', 'kloof'), ('kloof', 'korst'), ('korst', '   '), ('   ', 'Wassen'), ('Wassen', 'water'), ('water', 'zeep'), ('zeep', 'maken'), ('maken', 'eczeem'), ('eczeem', 'erg'), ('erg', '   '), ('   ', '2'), ('2', '3'), ('3', 'keer'), ('keer', 'week'), ('week', 'douchen/baden'), ('douchen/baden', 'genoeg'), ('genoeg', 'liefst'), ('liefst', 'zeep'), ('zeep', '   '), ('   ', 'Smeer'), ('Smeer', 'dag'), ('dag', 'verzachten'), ('verzachten', 'zalf'), ('zalf', 'crème'), ('crème', 'eczeem'), ('eczeem', 'laneten'), ('laneten', 'crème'), ('crème', 'koelzalf'), ('koelzalf', '    '), ('    ', 'soms'), ('soms', 'hormoonzalf'), ('hormoonzalf', 'nodig'), ('nodig', '   '), ('   ', 'eczeem'), ('eczeem', 'kans'), ('kans', 'hooikoort'), ('hooikoort', 'astma')]
# Allergie NOUN ROOT
# . PUNCT punct
#    SPACE dep
# Klachten NOUN nsubj
# bij ADP case
# een DET det
# allergie NOUN nmod
# zijn AUX cop
# bijvoorbeeld ADV advmod
# jeuk NOUN ROOT
# of CCONJ cc
# vlekjes NOUN conj
# op ADP case
# de DET det
# huid NOUN nmod
# , PUNCT punct
# dikke ADJ amod
# oogleden NOUN conj
# , PUNCT punct
# tranende VERB amod
# ogen NOUN conj
# , PUNCT punct
# kriebel VERB conj
# in ADP case
# de DET det
# neus NOUN obl
# , PUNCT punct
# tintelingen NOUN conj
# van ADP case
# de DET det
# tong NOUN nmod
# , PUNCT punct
# hoesten NOUN conj
# en CCONJ cc
# niezen VERB conj
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# bent AUX cop
# dan ADV advmod
# allergisch ADJ ROOT
# voor ADP case
# iets PRON obl
# , PUNCT punct
# zoals SCONJ mark
# stuifmeel NOUN nmod
# ( PUNCT punct
# hooikoorts NOUN nmod
# ) PUNCT punct
# , PUNCT punct
# schimmels NOUN conj
# , PUNCT punct
# huidschilfers NOUN conj
# van ADP case
# dieren NOUN nmod
# , PUNCT punct
# huisstofmijt NOUN conj
# , PUNCT punct
# make-up NOUN conj
# of CCONJ cc
# bepaalde VERB amod
# voeding NOUN conj
# ( PUNCT punct
# pinda's NOUN nmod
# , PUNCT punct
# eieren NOUN conj
# ) PUNCT punct
# . PUNCT punct
#     SPACE dep
# Uw PRON nmod:poss
# lichaam NOUN nsubj
# reageert VERB ROOT
# dan SCONJ advmod
# overdreven ADJ xcomp
# op ADP case
# een DET det
# stof NOUN obl
# . PUNCT punct
#     SPACE dep
# Schrijf PROPN ROOT
# op ADP case
# welke DET det
# klachten NOUN nmod
# u PRON nsubj
# krijgt VERB ROOT
# op ADP case
# welke DET det
# momenten NOUN obl
# . PUNCT punct
# Zo ADV advmod
# komt VERB ROOT
# u PRON nsubj
# te ADP mark
# weten VERB xcomp
# waar ADV advmod
# u PRON nsubj
# allergisch ADJ ccomp
# voor ADP cop
# bent AUX cop
# . PUNCT punct
#     SPACE dep
# Zorg NOUN nsubj
# ervoor ADV case
# dat SCONJ mark
# u PRON nsubj
# niet ADV advmod
# in ADP case
# contact NOUN obl
# komt VERB ROOT
# daarmee ADV advmod
# . PUNCT punct
#     SPACE dep
# Met ADP case
# medicijnen NOUN obl
# kunt AUX aux
# u PRON nsubj
# de DET det
# klachten NOUN obj
# ook ADV advmod
# verminderen VERB ROOT
# . PUNCT punct
# ['allergie', '  ', 'klacht', 'allergie', 'jeuk', 'vlek', 'huid', 'dik', 'ooglid', 'tranen', 'oog', 'Kriebel', 'neus', 'tinteling', 'tong', 'hoesten', 'niezen', '   ', 'allergisch', 'stuifmeel', 'hooikoorts', 'schimmel', 'huidschilfer', 'dier', 'huisstofmijt', 'make-up', 'bepalen', 'voeding', 'pinda', 'ei', '   ', 'lichaam', 'reageren', 'overdreven', 'stof', '   ', 'Schrijf', 'klacht', 'krijgen', 'moment', 'komen', 'weten', 'allergisch', '   ', 'zorg', 'ervoor', 'contact', 'komen', 'daarmee', '   ', 'medicijn', 'klacht', 'verminderen']
# [('allergie', '  '), ('  ', 'klacht'), ('klacht', 'allergie'), ('allergie', 'jeuk'), ('jeuk', 'vlek'), ('vlek', 'huid'), ('huid', 'dik'), ('dik', 'ooglid'), ('ooglid', 'tranen'), ('tranen', 'oog'), ('oog', 'Kriebel'), ('Kriebel', 'neus'), ('neus', 'tinteling'), ('tinteling', 'tong'), ('tong', 'hoesten'), ('hoesten', 'niezen'), ('niezen', '   '), ('   ', 'allergisch'), ('allergisch', 'stuifmeel'), ('stuifmeel', 'hooikoorts'), ('hooikoorts', 'schimmel'), ('schimmel', 'huidschilfer'), ('huidschilfer', 'dier'), ('dier', 'huisstofmijt'), ('huisstofmijt', 'make-up'), ('make-up', 'bepalen'), ('bepalen', 'voeding'), ('voeding', 'pinda'), ('pinda', 'ei'), ('ei', '   '), ('   ', 'lichaam'), ('lichaam', 'reageren'), ('reageren', 'overdreven'), ('overdreven', 'stof'), ('stof', '   '), ('   ', 'Schrijf'), ('Schrijf', 'klacht'), ('klacht', 'krijgen'), ('krijgen', 'moment'), ('moment', 'komen'), ('komen', 'weten'), ('weten', 'allergisch'), ('allergisch', '   '), ('   ', 'zorg'), ('zorg', 'ervoor'), ('ervoor', 'contact'), ('contact', 'komen'), ('komen', 'daarmee'), ('daarmee', '   '), ('   ', 'medicijn'), ('medicijn', 'klacht'), ('klacht', 'verminderen')]
# Droge ADJ amod
# huid NOUN ROOT
# . PUNCT punct
#    SPACE dep
# Een DET det
# droge ADJ amod
# huid NOUN nsubj
# is AUX cop
# gevoelig ADJ ROOT
# , PUNCT punct
# schilfert VERB conj
# vaak ADJ advmod
# en CCONJ cc
# kan AUX aux
# jeuken VERB conj
# . PUNCT punct
#     SPACE dep
# Ga VERB ROOT
# niet ADV advmod
# te ADV advmod
# vaak ADJ advmod
# en CCONJ cc
# te ADV advmod
# lang ADJ conj
# onder ADP case
# de DET det
# douche NOUN obl
# of CCONJ cc
# in ADP case
# bad NOUN conj
# . PUNCT punct
#     SPACE dep
# Gebruik NOUN amod
# lauw ADJ nmod
# of CCONJ cc
# warm ADJ conj
# water NOUN ROOT
# . PUNCT punct
#     SPACE dep
# Gebruik NOUN nsubj
# weinig ADV advmod
# zeep ADJ ROOT
# . PUNCT punct
# Zeep PROPN nsubj
# droogt VERB ROOT
# de DET det
# huid NOUN nsubj
# uit ADP compound:prt
# . PUNCT punct
#      SPACE dep
# Smeer VERB ROOT
# uw PRON nmod:poss
# droge ADJ amod
# huid NOUN obj
# in ADP compound:prt
# met ADP case
# een DET det
# vette ADJ amod
# zalf NOUN obl
# of CCONJ cc
# crème NOUN conj
# . PUNCT punct
# ['Droge', 'huid', '  ', 'droog', 'huid', 'gevoelig', 'schilferen', 'jeuken', '   ', 'Ga', 'douche', 'bad', '   ', 'Gebruik', 'lauw', 'warm', 'water', '   ', 'gebruik', 'zeep', 'zeep', 'droogt', 'huid', '    ', 'Smeer', 'droog', 'huid', 'vet', 'zalf', 'crème']
# [('Droge', 'huid'), ('huid', '  '), ('  ', 'droog'), ('droog', 'huid'), ('huid', 'gevoelig'), ('gevoelig', 'schilferen'), ('schilferen', 'jeuken'), ('jeuken', '   '), ('   ', 'Ga'), ('Ga', 'douche'), ('douche', 'bad'), ('bad', '   '), ('   ', 'Gebruik'), ('Gebruik', 'lauw'), ('lauw', 'warm'), ('warm', 'water'), ('water', '   '), ('   ', 'gebruik'), ('gebruik', 'zeep'), ('zeep', 'zeep'), ('zeep', 'droogt'), ('droogt', 'huid'), ('huid', '    '), ('    ', 'Smeer'), ('Smeer', 'droog'), ('droog', 'huid'), ('huid', 'vet'), ('vet', 'zalf'), ('zalf', 'crème')]
# Jeuk NOUN ROOT
# . PUNCT punct
#    SPACE dep
# Jeuk NOUN nsubj
# kan AUX aux
# allerlei DET det
# oorzaken NOUN obj
# hebben AUX ROOT
# , PUNCT punct
# zoals SCONJ mark
# een DET det
# droge ADJ amod
# huid NOUN advcl
# , PUNCT punct
# een DET det
# allergie NOUN conj
# , PUNCT punct
# galbulten NOUN conj
# , PUNCT punct
# eczeem NOUN conj
# of CCONJ cc
# schurft NOUN conj
# . PUNCT punct
#       SPACE dep
# Hoe ADV advmod
# moeilijk ADJ ROOT
# het PRON nsubj
# ook ADV advmod
# is AUX cop
# : PUNCT punct
# probeer VERB ROOT
# niet ADV advmod
# te ADP mark
# krabben VERB ccomp
# . PUNCT punct
#     SPACE dep
# Probeer VERB advmod
# te ADP mark
# zorgen VERB ROOT
# dat SCONJ mark
# uw PRON nmod:poss
# huid NOUN nsubj
# niet ADV advmod
# uitdroogt VERB ccomp
# : PUNCT punct
#     SPACE dep
# ga VERB ROOT
# niet ADV advmod
# te ADV advmod
# vaak ADJ xcomp
# , PUNCT punct
# lang ADJ conj
# en CCONJ cc
# heet VERB conj
# douchen VERB xcomp
# of CCONJ cc
# in ADP case
# bad NOUN nmod
#      SPACE dep
# gebruik NOUN obl
# geen DET nmod
# of CCONJ cc
# weinig PRON conj
# zeep NOUN xcomp
#      SPACE dep
# ...
# . PUNCT punct
#    SPACE dep
# Vogelgriep PROPN nsubj
# is AUX cop
# een DET det
# ziekte NOUN ROOT
# bij ADP case
# pluimvee NOUN nmod
# ( PUNCT punct
# bijvoorbeeld ADV amod
# kippen NOUN nmod
# ) PUNCT punct
# en CCONJ cc
# sommige DET det
# wilde NOUN conj
# vogelsoorten VERB xcomp
# ( PUNCT punct
# zoals SCONJ mark
# zwanen PROPN advcl
# ) PUNCT punct
# . PUNCT punct
#     SPACE dep
# Vogelgriep PROPN nsubj
# is AUX cop
# heel ADJ advmod
# besmettelijk ADJ ROOT
# voor ADP case
# andere ADJ amod
# vogels NOUN obl
# . PUNCT punct
#     SPACE dep
# Heel ADJ advmod
# soms ADV advmod
# kunnen AUX aux
# zieke ADJ amod
# vogels NOUN nsubj
# ook ADV advmod
# mensen NOUN nsubj
# besmetten VERB ROOT
# . PUNCT punct
#     SPACE dep
# Dat PRON nsubj
# gebeurt VERB ROOT
# alleen ADV advmod
# als SCONJ mark
# iemand PRON nsubj
# vaak ADJ advmod
# dichtbij ADJ case
# vogels NOUN obl
# komt VERB advcl
# , PUNCT punct
# bijvoorbeeld ADV amod
# door ADP case
# zijn PRON nmod:poss
# werk NOUN obl
# . PUNCT punct
#     SPACE dep
# De DET det
# oorzaak NOUN nsubj
# van ADP case
# vogelgriep VERB nmod
# is AUX cop
# een DET det
# virus NOUN ROOT
# . PUNCT punct
# Er ADV advmod
# zijn VERB ROOT
# verschillende ADJ amod
# vogelgriepvirussen NOUN nsubj
# . PUNCT punct
#     SPACE dep
# Ieder DET det
# jaar NOUN obl
# wordt AUX aux:pass
# bij ADP case
# een DET det
# paar NOUN nmod
# pluimveebedrijven NOUN nsubj:pass
# in ADP case
# Nederland PROPN nmod
# vogelgriep VERB xcomp
# gevonden VERB ROOT
# . PUNCT punct
#     SPACE dep
# Had AUX aux
# u PRON nsubj:pass
# de DET det
# afgelopen VERB amod
# 14 NUM nummod
# dagen NOUN obl
# contact NOUN obl
# met ADP case
# vogels NOUN obl
# waarbij ADV advmod
# vogelgriep VERB nsubj:pass
# is AUX aux:pass
# gevonden VERB ROOT
# en CCONJ cc
# krijgt VERB conj
# u PRON nsubj
# klachten NOUN obj
# als SCONJ mark
# koorts NOUN xcomp
# en CCONJ cc
# spierpijn NOUN conj
# ? PUNCT punct
# Bel PROPN ROOT
# dan SCONJ mark
# uw PRON nmod:poss
# huisarts NOUN parataxis
# . PUNCT punct
# ['Vogelgriep', '  ', 'vogelgriep', 'ziekte', 'Pluimvee', 'kip', 'vogelsoorten', 'zwan', '   ', 'Vogelgriep', 'heel', 'besmettelijk', 'vogel', '   ', 'heel', 'soms', 'ziek', 'vogel', 'mens', 'besmetten', '   ', 'gebeuren', 'dichtbij', 'vogel', 'komen', 'werk', '   ', 'oorzaak', 'Vogelgriep', 'virus', 'verschillend', 'vogelgriepviruss', '   ', 'jaar', 'paar', 'pluimveebedrijov', 'Nederland', 'vogelgriep', 'vinden', '   ', '14', 'dag', 'contact', 'vogel', 'waarbij', 'vogelgropen', 'vinden', 'krijgen', 'klacht', 'koorts', 'spierpijn', 'Bel', 'huisarts']
# [('Vogelgriep', '  '), ('  ', 'vogelgriep'), ('vogelgriep', 'ziekte'), ('ziekte', 'Pluimvee'), ('Pluimvee', 'kip'), ('kip', 'vogelsoorten'), ('vogelsoorten', 'zwan'), ('zwan', '   '), ('   ', 'Vogelgriep'), ('Vogelgriep', 'heel'), ('heel', 'besmettelijk'), ('besmettelijk', 'vogel'), ('vogel', '   '), ('   ', 'heel'), ('heel', 'soms'), ('soms', 'ziek'), ('ziek', 'vogel'), ('vogel', 'mens'), ('mens', 'besmetten'), ('besmetten', '   '), ('   ', 'gebeuren'), ('gebeuren', 'dichtbij'), ('dichtbij', 'vogel'), ('vogel', 'komen'), ('komen', 'werk'), ('werk', '   '), ('   ', 'oorzaak'), ('oorzaak', 'Vogelgriep'), ('Vogelgriep', 'virus'), ('virus', 'verschillend'), ('verschillend', 'vogelgriepviruss'), ('vogelgriepviruss', '   '), ('   ', 'jaar'), ('jaar', 'paar'), ('paar', 'pluimveebedrijov'), ('pluimveebedrijov', 'Nederland'), ('Nederland', 'vogelgriep'), ('vogelgriep', 'vinden'), ('vinden', '   '), ('   ', '14'), ('14', 'dag'), ('dag', 'contact'), ('contact', 'vogel'), ('vogel', 'waarbij'), ('waarbij', 'vogelgropen'), ('vogelgropen', 'vinden'), ('vinden', 'krijgen'), ('krijgen', 'klacht'), ('klacht', 'koorts'), ('koorts', 'spierpijn'), ('spierpijn', 'Bel'), ('Bel', 'huisarts')]
# Bloed NOUN nsubj
# ophoesten VERB ROOT
# . PUNCT punct
#    SPACE dep
# Bij ADP case
# bloed NOUN obl
# ophoesten NOUN appos
# zit VERB ROOT
# er ADV advmod
# meestal ADV advmod
# een DET det
# stipje NOUN nmod
# of CCONJ cc
# streepje NOUN conj
# bloed NOUN nsubj
# in ADP case
# uw PRON nmod:poss
# slijm NOUN nmod
# . PUNCT punct
#     SPACE dep
# Meestal ADV advmod
# is AUX cop
# de DET det
# oorzaak NOUN nsubj
# een DET det
# luchtweginfectie NOUN ROOT
# , PUNCT punct
# zoals SCONJ mark
# bronchitis ADJ nmod
# of CCONJ cc
# longontsteking NOUN conj
# . PUNCT punct
#      SPACE dep
# Het PRON nsubj
# kan AUX aux
# ook ADV advmod
# komen VERB ROOT
# door ADP case
# COPD PROPN obl
# of CCONJ cc
# longkanker NOUN conj
# . PUNCT punct
#     SPACE dep
# Bel PROPN ROOT
# uw PRON nmod:poss
# huisarts NOUN obl
# als SCONJ mark
# u PRON nsubj
# een DET det
# keer NOUN nmod
# of CCONJ cc
# vaker ADJ conj
# een DET det
# beetje NOUN nmod
# bloed NOUN obj
# ophoest VERB xcomp
# . PUNCT punct
#     SPACE dep
# Bel PROPN nsubj
# direct ADJ amod
# de DET det
# huisarts NOUN parataxis
# of CCONJ cc
# huisartsenpost VERB ROOT
# als SCONJ mark
# u PRON nsubj
# veel DET det
# bloed NOUN obj
# ophoest VERB advcl
# , PUNCT punct
# bijvoorbeeld ADV amod
# een DET det
# lepel NOUN parataxis
# vol. X nmod
# ['bloed', 'ophoesten', '  ', 'bloed', 'ophoest', 'zitten', 'meestal', 'stip', 'streep', 'bloed', 'slijm', '   ', 'meestal', 'oorzaak', 'luchtweginfectie', 'bronchitis', 'longontsteking', '    ', 'komen', 'COPD', 'longkanker', '   ', 'Bel', 'huisarts', 'keer', 'vaak', 'beetje', 'bloed', 'ophoesn', '   ', 'Bel', 'direct', 'huisarts', 'huisartsenpost', 'bloed', 'ophoezen', 'lepel', 'voamelijk']
# [('bloed', 'ophoesten'), ('ophoesten', '  '), ('  ', 'bloed'), ('bloed', 'ophoest'), ('ophoest', 'zitten'), ('zitten', 'meestal'), ('meestal', 'stip'), ('stip', 'streep'), ('streep', 'bloed'), ('bloed', 'slijm'), ('slijm', '   '), ('   ', 'meestal'), ('meestal', 'oorzaak'), ('oorzaak', 'luchtweginfectie'), ('luchtweginfectie', 'bronchitis'), ('bronchitis', 'longontsteking'), ('longontsteking', '    '), ('    ', 'komen'), ('komen', 'COPD'), ('COPD', 'longkanker'), ('longkanker', '   '), ('   ', 'Bel'), ('Bel', 'huisarts'), ('huisarts', 'keer'), ('keer', 'vaak'), ('vaak', 'beetje'), ('beetje', 'bloed'), ('bloed', 'ophoesn'), ('ophoesn', '   '), ('   ', 'Bel'), ('Bel', 'direct'), ('direct', 'huisarts'), ('huisarts', 'huisartsenpost'), ('huisartsenpost', 'bloed'), ('bloed', 'ophoezen'), ('ophoezen', 'lepel'), ('lepel', 'voamelijk')]
# Vitiligo PROPN ROOT
# . PUNCT punct
#    SPACE dep
# Vitiligo PROPN nsubj
# is AUX cop
# een DET det
# aandoening NOUN ROOT
# waarbij ADV advmod
# de DET det
# pigmentcellen NOUN nsubj
# verdwijnen VERB acl:relcl
# uit ADP case
# huid NOUN obl
# en CCONJ cc
# haar PRON conj
# . PUNCT punct
#    SPACE dep
# Er ADV advmod
# ontstaan VERB ROOT
# melkwitte ADJ amod
# plekken VERB nsubj
# van ADP case
# verschillende ADJ amod
# grootte NOUN nmod
# en CCONJ cc
# vorm NOUN conj
# , PUNCT punct
# die PRON nsubj
# in ADP case
# de DET fixed
# loop NOUN fixed
# van ADP fixed
# de DET det
# tijd NOUN obl
# kunnen AUX aux
# veranderen VERB acl:relcl
# . PUNCT punct
#    SPACE dep
# De DET det
# oorzaak NOUN nsubj
# is AUX cop
# onbekend ADJ ROOT
# . PUNCT punct
#    SPACE dep
# Het DET det
# effect NOUN nsubj
# van ADP case
# de DET det
# verschillende ADJ amod
# behandelingen NOUN nmod
# is AUX cop
# matig ADJ ROOT
# . PUNCT punct
# ['Vitiligo', '  ', 'Vitiligo', 'aandoening', 'waarbij', 'pigmentcell', 'verdwijnen', 'huid', '  ', 'ontstaan', 'melkwiten', 'plek', 'verschillend', 'grootte', 'vorm', 'loop', 'tijd', 'veranderen', '  ', 'oorzaak', 'onbekend', '  ', 'effect', 'verschillend', 'behandeling', 'matig']
# [('Vitiligo', '  '), ('  ', 'Vitiligo'), ('Vitiligo', 'aandoening'), ('aandoening', 'waarbij'), ('waarbij', 'pigmentcell'), ('pigmentcell', 'verdwijnen'), ('verdwijnen', 'huid'), ('huid', '  '), ('  ', 'ontstaan'), ('ontstaan', 'melkwiten'), ('melkwiten', 'plek'), ('plek', 'verschillend'), ('verschillend', 'grootte'), ('grootte', 'vorm'), ('vorm', 'loop'), ('loop', 'tijd'), ('tijd', 'veranderen'), ('veranderen', '  '), ('  ', 'oorzaak'), ('oorzaak', 'onbekend'), ('onbekend', '  '), ('  ', 'effect'), ('effect', 'verschillend'), ('verschillend', 'behandeling'), ('behandeling', 'matig')]
# Downsyndroom PROPN ROOT
# . PUNCT punct
#    SPACE dep
# Kinderen NOUN nsubj
# met ADP case
# downsyndroom NOUN nmod
# : PUNCT punct
#     SPACE dep
# hebben VERB aux
# een DET det
# verstandelijke ADJ amod
# beperking NOUN nsubj
#      SPACE dep
# kunnen AUX aux
# verschillende ADJ amod
# problemen NOUN obj
# met ADP case
# de DET det
# gezondheid NOUN nmod
# hebben VERB aux
#      SPACE dep
# hebben AUX ROOT
# soms ADV advmod
# problemen NOUN obj
# met ADP case
# emoties NOUN nmod
# en CCONJ cc
# gedrag NOUN conj
#         SPACE dep
# Hoe ADV advmod
# erg ADJ amod
# die DET det
# problemen NOUN nsubj
# zijn AUX cop
# , PUNCT punct
# verschilt VERB ROOT
# per ADP case
# kind NOUN obl
# . PUNCT punct
#     SPACE dep
# Voor ADP case
# de DET det
# problemen NOUN obl
# met ADP case
# de DET det
# gezondheid NOUN nmod
# krijgt VERB ROOT
# uw PRON nmod:poss
# kind NOUN nsubj
# meestal ADV advmod
# hulp NOUN obj
# van ADP case
# een DET det
# kinderarts NOUN nmod
# , PUNCT punct
# keel-neus-oor-arts PROPN conj
# , PUNCT punct
# oogarts NOUN conj
# , PUNCT punct
# logopedist NOUN conj
# en CCONJ cc
# kinderfysiotherapeut NOUN conj
# . PUNCT punct
#     SPACE dep
# Zij PRON nsubj
# helpen VERB ROOT
# uw PRON nmod:poss
# kind NOUN obj
# zo ADV advmod
# gezond ADJ advmod
# mogelijk ADJ advcl
# groot ADJ xcomp
# te ADP mark
# worden AUX xcomp
# . PUNCT punct
#     SPACE dep
# Uw PRON nmod:poss
# kind NOUN nsubj
# heeft VERB ROOT
# veel DET det
# steun NOUN obj
# , PUNCT punct
# aandacht NOUN conj
# en CCONJ cc
# liefde NOUN conj
# van ADP case
# u PRON nmod
# nodig ADJ xcomp
# . PUNCT punct
# ['Downsyndroom', '  ', 'Kind', 'downsyndroom', '   ', 'verstandelijk', 'beperking', '    ', 'verschillend', 'probleem', 'gezondheid', '    ', 'soms', 'probleem', 'emotie', 'gedrag', '       ', 'erg', 'probleem', 'verschillen', 'kind', '   ', 'probleem', 'gezondheid', 'krijgen', 'kind', 'meestal', 'hulp', 'kinderarts', 'keel-neus-oor-arts', 'oogart', 'logopedist', 'kinderfysiotherapeut', '   ', 'helpen', 'kind', 'gezond', 'groot', '   ', 'kind', 'steun', 'aandacht', 'liefde', 'nodig']
# [('Downsyndroom', '  '), ('  ', 'Kind'), ('Kind', 'downsyndroom'), ('downsyndroom', '   '), ('   ', 'verstandelijk'), ('verstandelijk', 'beperking'), ('beperking', '    '), ('    ', 'verschillend'), ('verschillend', 'probleem'), ('probleem', 'gezondheid'), ('gezondheid', '    '), ('    ', 'soms'), ('soms', 'probleem'), ('probleem', 'emotie'), ('emotie', 'gedrag'), ('gedrag', '       '), ('       ', 'erg'), ('erg', 'probleem'), ('probleem', 'verschillen'), ('verschillen', 'kind'), ('kind', '   '), ('   ', 'probleem'), ('probleem', 'gezondheid'), ('gezondheid', 'krijgen'), ('krijgen', 'kind'), ('kind', 'meestal'), ('meestal', 'hulp'), ('hulp', 'kinderarts'), ('kinderarts', 'keel-neus-oor-arts'), ('keel-neus-oor-arts', 'oogart'), ('oogart', 'logopedist'), ('logopedist', 'kinderfysiotherapeut'), ('kinderfysiotherapeut', '   '), ('   ', 'helpen'), ('helpen', 'kind'), ('kind', 'gezond'), ('gezond', 'groot'), ('groot', '   '), ('   ', 'kind'), ('kind', 'steun'), ('steun', 'aandacht'), ('aandacht', 'liefde'), ('liefde', 'nodig')]
# Trombose SYM nsubj
# in ADP ROOT
# het DET fixed
# oog NOUN fixed
# . PUNCT punct
#    SPACE dep
# Bij ADP case
# trombose NOUN obl
# in ADP compound:prt
# het DET fixed
# oog NOUN fixed
# zitten VERB ROOT
# 1 NUM nummod
# of CCONJ cc
# meer PRON conj
# bloedvaten NOUN nsubj
# in ADP case
# uw PRON nmod:poss
# oog NOUN obl
# dicht ADJ compound:prt
# . PUNCT punct
#     SPACE dep
# Dit PRON nsubj
# kan AUX aux
# komen VERB ROOT
# door ADP case
# een DET det
# bloedpropje NOUN obl
# . PUNCT punct
#     SPACE dep
# De DET det
# behandeling NOUN nsubj
# kan AUX aux
# met ADP case
# prikken NOUN ROOT
# in ADP case
# het DET fixed
# oog NOUN fixed
# of CCONJ fixed
# met ADP case
# een DET det
# laser NOUN nmod
# . PUNCT punct
#     SPACE dep
# Na ADP case
# de DET det
# behandeling NOUN obl
# kunt AUX aux
# u PRON nsubj
# minder ADV advmod
# goed ADJ ROOT
# of CCONJ cc
# niet ADV advmod
# meer ADV advmod
# zien VERB conj
# met ADP case
# het DET det
# oog NOUN obl
# . PUNCT punct
#     SPACE dep
# U PRON nsubj
# kunt AUX aux
# hulp NOUN obj
# krijgen VERB ROOT
# voor ADP case
# aanpassingen NOUN obl
# op ADP case
# uw PRON nmod:poss
# werk NOUN nmod
# of CCONJ cc
# in ADP case
# het DET det
# dagelijks ADJ amod
# leven NOUN conj
# . PUNCT punct
#     SPACE dep
# Gezond ADJ nsubj
# leven NOUN fixed
# verkleint VERB ROOT
# de DET det
# kans NOUN obj
# dat SCONJ mark
# u PRON nsubj
# weer ADV advmod
# trombose NOUN obj
# in ADP compound:prt
# het DET fixed
# oog NOUN fixed
# krijgt VERB acl
# . PUNCT punct
# Bijvoorbeeld ADV advmod
# niet ADV advmod
# roken VERB ROOT
# en CCONJ cc
# genoeg ADV advmod
# bewegen VERB conj
# . PUNCT punct
# ['Trombose', 'oog', '  ', 'trombose', 'oog', 'voorzitten', '1', 'bloedva', 'oog', 'dicht', '   ', 'komen', 'bloedprop', '   ', 'behandeling', 'prikken', 'oog', 'laser', '   ', 'behandeling', 'goed', 'zien', 'oog', '   ', 'hulp', 'krijgen', 'aanpassing', 'werk', 'dagelijks', 'leven', '   ', 'gezond', 'leven', 'verkleinnen', 'kans', 'trombose', 'oog', 'krijgen', 'roken', 'genoeg', 'bewegen']
# [('Trombose', 'oog'), ('oog', '  '), ('  ', 'trombose'), ('trombose', 'oog'), ('oog', 'voorzitten'), ('voorzitten', '1'), ('1', 'bloedva'), ('bloedva', 'oog'), ('oog', 'dicht'), ('dicht', '   '), ('   ', 'komen'), ('komen', 'bloedprop'), ('bloedprop', '   '), ('   ', 'behandeling'), ('behandeling', 'prikken'), ('prikken', 'oog'), ('oog', 'laser'), ('laser', '   '), ('   ', 'behandeling'), ('behandeling', 'goed'), ('goed', 'zien'), ('zien', 'oog'), ('oog', '   '), ('   ', 'hulp'), ('hulp', 'krijgen'), ('krijgen', 'aanpassing'), ('aanpassing', 'werk'), ('werk', 'dagelijks'), ('dagelijks', 'leven'), ('leven', '   '), ('   ', 'gezond'), ('gezond', 'leven'), ('leven', 'verkleinnen'), ('verkleinnen', 'kans'), ('kans', 'trombose'), ('trombose', 'oog'), ('oog', 'krijgen'), ('krijgen', 'roken'), ('roken', 'genoeg'), ('genoeg', 'bewegen')]
# Dikkere ADJ amod
# borsten NOUN ROOT
# bij ADP case
# mannen NOUN nmod
# . PUNCT punct
#    SPACE dep
# Dikkere ADJ amod
# borsten NOUN nsubj
# komen VERB ROOT
# bij ADP case
# pubers NOUN obl
# en CCONJ cc
# bij ADP case
# mannen NOUN obl
# ouder ADJ conj
# dan SCONJ mark
# 50 NUM nummod
# jaar NOUN advcl
# vaak ADJ advmod
# door ADP case
# veranderingen NOUN obl
# in ADP case
# hormonen NOUN nmod
# . PUNCT punct
#     SPACE dep
# Het PRON nsubj
# kan AUX aux
# ook ADV advmod
# komen VERB ROOT
# door ADP case
# overgewicht NOUN obl
# , PUNCT punct
# medicijnen NOUN conj
# , PUNCT punct
# een DET det
# ziekte NOUN obj
# of CCONJ cc
# anabole NOUN nmod
# steroïden VERB conj
# ( PUNCT punct
# bij ADP case
# bodybuilding NOUN obl
# ) PUNCT punct
# . PUNCT punct
#     SPACE dep
# Bij ADP case
# de DET det
# meeste ADV amod
# pubers NOUN obl
# gaat VERB ROOT
# het PRON nsubj
# vanzelf ADV advmod
# weg ADV compound:prt
# . PUNCT punct
# Bij ADP case
# mannen NOUN obl
# boven ADP case
# de DET det
# 50 NUM nummod
# jaar NOUN nmod
# meestal ADV nmod
# niet ADV ROOT
# . PUNCT punct
#      SPACE dep
# Een DET det
# behandeling NOUN nsubj
# is AUX cop
# vaak ADJ advmod
# niet ADV advmod
# nodig ADJ ROOT
# . PUNCT punct
#      SPACE dep
# Bent AUX ROOT
# u PRON nsubj
# tussen ADP case
# de DET det
# 16 NUM obl
# en CCONJ cc
# 50 NUM nummod
# jaar NOUN conj
# ? PUNCT punct
# Bel PROPN ROOT
# dan ADV advmod
# altijd ADV advmod
# uw PRON nmod:poss
# huisarts NOUN obj
# . PUNCT punct
# Er ADV advmod
# kan AUX aux
# verder ADJ advmod
# onderzoek NOUN nsubj
# nodig ADJ ROOT
# zijn AUX cop
# . PUNCT punct
# ['dikkere', 'borst', 'man', '  ', 'dikkere', 'borst', 'komen', 'puber', 'man', 'oud', '50', 'jaar', 'verandering', 'Hormonen', '   ', 'komen', 'overgewicht', 'medicijn', 'ziekte', 'Anabole', 'steroïden', 'bodybuilding', '   ', 'veel', 'puber', 'gaan', 'vanzelf', 'man', '50', 'jaar', 'meestal', '    ', 'behandeling', 'nodig', '    ', '16', '50', 'jaar', 'Bel', 'huisarts', 'onderzoek', 'nodig']
# [('dikkere', 'borst'), ('borst', 'man'), ('man', '  '), ('  ', 'dikkere'), ('dikkere', 'borst'), ('borst', 'komen'), ('komen', 'puber'), ('puber', 'man'), ('man', 'oud'), ('oud', '50'), ('50', 'jaar'), ('jaar', 'verandering'), ('verandering', 'Hormonen'), ('Hormonen', '   '), ('   ', 'komen'), ('komen', 'overgewicht'), ('overgewicht', 'medicijn'), ('medicijn', 'ziekte'), ('ziekte', 'Anabole'), ('Anabole', 'steroïden'), ('steroïden', 'bodybuilding'), ('bodybuilding', '   '), ('   ', 'veel'), ('veel', 'puber'), ('puber', 'gaan'), ('gaan', 'vanzelf'), ('vanzelf', 'man'), ('man', '50'), ('50', 'jaar'), ('jaar', 'meestal'), ('meestal', '    '), ('    ', 'behandeling'), ('behandeling', 'nodig'), ('nodig', '    '), ('    ', '16'), ('16', '50'), ('50', 'jaar'), ('jaar', 'Bel'), ('Bel', 'huisarts'), ('huisarts', 'onderzoek'), ('onderzoek', 'nodig')]

# %%
#
